# %% [markdown]
# # Validation of Experiment 1 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from temporal_reuma import main_algorithm
from encoder_sequence import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
#read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/bio_corrente_sequence.csv',sep = ';')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'average'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,10)}
    for k in range(2,10):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,10):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,10):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,10), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.679461533607
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.679461533607
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.679461533607
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.679461533607
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.679461533607
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.679461533607
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.718608025109
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.996312         0.647752               0.998149   0.996312
#                    3  0.997349         0.891065               0.99866    0.997326
#                    4  0.993598         0.838313               0.996741   0.993506
#                    5  0.995331         0.913083               0.997604   0.995222
#                    6  0.994212         0.911518               0.997015   0.994055
#                    7  0.988106         0.836402               0.993844   0.987748
#                    8  0.982232         0.773197               0.990785   0.981679
#                    9  0.989518         0.887335               0.994506   0.989058
# Cophenetic Correlation Coefficient: 0.798068108455
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998584         0.981196               0.999265   0.998571
#                    3  0.998385         0.986532               0.999135   0.998282
#                    4  0.998968         0.993532               0.999435   0.998872
#                    5  0.998882         0.993089               0.999386   0.998775
#                    6  0.998891         0.993196               0.999391   0.998784
#                    7  0.998898         0.993165               0.999395   0.998794
#                    8  0.998578         0.991153               0.99922    0.998444
#                    9  0.997772         0.986234               0.998778   0.997564
# Cophenetic Correlation Coefficient: 0.865824794721
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.978088         0.779925               0.988443   0.97801
#                    3  0.998715         0.992478               0.999292   0.998591
#                    4  0.999464         0.997104               0.999701   0.999404
#                    5  0.997202         0.986558               0.998417   0.996848
#                    6  0.98825          0.944735               0.993338   0.986753
#                    7  0.988814         0.949189               0.993624   0.987338
#                    8  0.987464         0.947149               0.992778   0.985696
#                    9  0.981759         0.926008               0.98944    0.979114
# Cophenetic Correlation Coefficient: 0.914158823093
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998839         0.990695               0.999379   0.998788
#                    3  0.995504         0.969474               0.997589   0.995256
#                    4  0.997344         0.987327               0.998499   0.997022
#                    5  0.99308          0.967577               0.996085   0.992244
#                    6  0.987943         0.948356               0.993069   0.986298
#                    7  0.976001         0.911649               0.985942   0.972539
#                    8  0.973898         0.915657               0.984129   0.968997
#                    9  0.948135         0.846996               0.967983   0.938116
# Cophenetic Correlation Coefficient: 0.866658496204
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.995637         0.953189               0.99771    0.995505
#                    3  0.986856         0.9221                 0.99292    0.98617
#                    4  0.995961         0.985287               0.997625   0.995355
#                    5  0.973877         0.918512               0.983816   0.96835
#                    6  0.963924         0.899293               0.977026   0.955863
#                    7  0.947167         0.863428               0.965757   0.935353
#                    8  0.874562         0.720851               0.915441   0.84601
#                    9  0.917364         0.834371               0.935589   0.88511
# Cophenetic Correlation Coefficient: 0.909425834861
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.995608         0.936935               0.997726   0.995519
#                    3  0.979063         0.876763               0.988493   0.977285
#                    4  0.980671         0.924161               0.988596   0.978375
#                    5  0.963404         0.930473               0.972991   0.952862
#                    6  0.98536          0.970136               0.983106   0.967662
#                    7  0.985676         0.97039                0.982728   0.966276
#                    8  0.979098         0.955947               0.973509   0.950256
#                    9  0.952251         0.897732               0.937557   0.885546
# Cophenetic Correlation Coefficient: 0.916699298906
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99533          0.931861               0.997584   0.995236
#                    3  0.982216         0.8958                 0.990381   0.981183
#                    4  0.991624         0.975118               0.994753   0.990507
#                    5  0.973103         0.950031               0.981256   0.967478
#                    6  0.999426         0.998833               0.99935    0.99872
#                    7  0.980185         0.959291               0.976688   0.954266
#                    8  0.987327         0.973691               0.98457    0.969862
#                    9  0.976688         0.950437               0.970053   0.943727
# Cophenetic Correlation Coefficient: 0.900305066322
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.994358         0.917661               0.997084   0.994243
#                    3  0.980288         0.884517               0.989378   0.979263
#                    4  0.994527         0.988927               0.996393   0.993756
#                    5  0.977789         0.958828               0.985014   0.974275
#                    6  0.999744         0.999481               0.999711   0.999424
#                    7  0.994194         0.988145               0.993287   0.986862
#                    8  0.986526         0.972343               0.984189   0.969357
#                    9  0.971472         0.94132                0.966321   0.934934
# Cophenetic Correlation Coefficient: 0.884159535098
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.9918           0.878059               0.99577    0.991635
#                    3  0.981677         0.894115               0.990108   0.980686
#                    4  0.993024         0.986496               0.995377   0.992022
#                    5  0.971058         0.945744               0.979088   0.963195
#                    6  0.996395         0.992687               0.995914   0.991951
#                    7  0.994764         0.989345               0.994012   0.988178
#                    8  0.987938         0.975282               0.985895   0.972655
#                    9  0.97061          0.939574               0.965309   0.933119
# Cophenetic Correlation Coefficient: 0.868638321718
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.989737         0.849077               0.994706   0.989526
#                    3  0.985237         0.91486                0.99202    0.984412
#                    4  0.993102         0.986829               0.995422   0.992111
#                    5  0.960882         0.926707               0.971297   0.949278
#                    6  0.994227         0.988294               0.993469   0.987133
#                    7  0.995204         0.990259               0.994554   0.989261
#                    8  0.993436         0.986624               0.992478   0.985166
#                    9  0.980668         0.960361               0.977458   0.956149
# Cophenetic Correlation Coefficient: 0.854857486524
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.984153         0.772196               0.991819   0.983817
#                    3  0.989644         0.940549               0.994374   0.988992
#                    4  0.990846         0.98145                0.99398    0.989553
#                    5  0.935547         0.879814               0.953979   0.919727
#                    6  0.991773         0.983595               0.991459   0.983521
#                    7  0.993556         0.986905               0.992671   0.985624
#                    8  0.989778         0.979038               0.988086   0.976959
#                    9  0.970477         0.939015               0.964916   0.932976
# Cophenetic Correlation Coefficient: 0.846602238056
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.988251         0.818629               0.993948   0.988008
#                    3  0.988736         0.939668               0.993781   0.987904
#                    4  0.990693         0.977645               0.994022   0.989347
#                    5  0.903898         0.821238               0.931873   0.882332
#                    6  0.983794         0.968632               0.98519    0.972506
#                    7  0.992614         0.984988               0.991581   0.98347
#                    8  0.990116         0.979774               0.988541   0.977666
#                    9  0.971236         0.940611               0.96586    0.93468
# Cophenetic Correlation Coefficient: 0.83385679264
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.988919         0.823695               0.994291   0.988697
#                    3  0.983735         0.91282                0.991003   0.982713
#                    4  0.988806         0.965867               0.993083   0.987232
#                    5  0.863108         0.745559               0.903536   0.834656
#                    6  0.97474          0.951633               0.978641   0.96122
#                    7  0.991839         0.983417               0.990702   0.98171
#                    8  0.989675         0.978885               0.98803    0.976637
#                    9  0.973827         0.946025               0.96904    0.940575
# Cophenetic Correlation Coefficient: 0.821733495969
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.982341         0.742675               0.990883   0.981995
#                    3  0.958222         0.777328               0.976885   0.956209
#                    4  0.979761         0.930723               0.987774   0.976811
#                    5  0.782949         0.597079               0.847197   0.741042
#                    6  0.945003         0.896524               0.957434   0.925642
#                    7  0.987578         0.975006               0.986485   0.973733
#                    8  0.987973         0.975454               0.986121   0.972803
#                    9  0.976231         0.951082               0.972013   0.946037
# Cophenetic Correlation Coefficient: 0.810501193932
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.979895         0.712305               0.989617   0.979495
#                    3  0.936522         0.653979               0.965041   0.934235
#                    4  0.976215         0.917909               0.985678   0.972726
#                    5  0.748931         0.533894               0.823212   0.701143
#                    6  0.930777         0.870115               0.947752   0.909546
#                    7  0.98818          0.976224               0.987177   0.974982
#                    8  0.988593         0.976722               0.986851   0.97412
#                    9  0.97626          0.951179               0.972115   0.946067
