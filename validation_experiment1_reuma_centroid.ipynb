# %% [markdown]
# # Validation of Experiment 1 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from temporal_reuma import main_algorithm
from encoder_sequence import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
#read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/bio_corrente_sequence.csv',sep = ';')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'centroid'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,10)}
    for k in range(2,10):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,10):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,10):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,10), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.665119925155
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.665119925155
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.665119925155
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.665119925155
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.665119925155
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.665119925155
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.712423297108
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.996455         0.483849               0.998223   0.996455
#                    3  0.996588         0.795139               0.998283   0.996572
#                    4  0.995121         0.821264               0.997532   0.995075
#                    5  0.993538         0.828903               0.996714   0.993446
#                    6  0.992162         0.83612                0.995994   0.992014
#                    7  0.990571         0.837888               0.995156   0.990345
#                    8  0.989904         0.851621               0.994786   0.989611
#                    9  0.988154         0.847353               0.993852   0.987757
# Cophenetic Correlation Coefficient: 0.78733389817
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99834          0.736                  0.999169   0.99834
#                    3  0.996889         0.816506               0.998434   0.996874
#                    4  0.995071         0.819509               0.997506   0.995024
#                    5  0.993563         0.829053               0.996727   0.993471
#                    6  0.992187         0.837324               0.996007   0.992038
#                    7  0.990449         0.836333               0.99509    0.990214
#                    8  0.990621         0.860121               0.995155   0.990343
#                    9  0.991853         0.892151               0.995769   0.991565
# Cophenetic Correlation Coefficient: 0.849010876864
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99834          0.736                  0.999169   0.99834
#                    3  0.996914         0.816506               0.998446   0.996899
#                    4  0.995247         0.82662                0.997595   0.995201
#                    5  0.993813         0.836599               0.996853   0.993723
#                    6  0.992213         0.837809               0.996019   0.992062
#                    7  0.9906           0.83956                0.995165   0.990363
#                    8  0.991609         0.873432               0.995665   0.991357
#                    9  0.993457         0.91218                0.996601   0.99322
# Cophenetic Correlation Coefficient: 0.875217627451
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99834          0.736                  0.999169   0.99834
#                    3  0.996839         0.813823               0.998409   0.996823
#                    4  0.995147         0.823657               0.997544   0.9951
#                    5  0.993688         0.833637               0.99679    0.993597
#                    6  0.992039         0.834875               0.995929   0.991884
#                    7  0.991267         0.849114               0.995511   0.991051
#                    8  0.991759         0.876032               0.995741   0.99151
#                    9  0.993829         0.917855               0.996793   0.993605
# Cophenetic Correlation Coefficient: 0.817195447778
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.993733         0.872928               0.996819   0.993709
#                    3  0.988203         0.917195               0.993704   0.987614
#                    4  0.999391         0.996898               0.999657   0.999316
#                    5  0.99939          0.996895               0.999657   0.999316
#                    6  0.999383         0.996855               0.999653   0.999307
#                    7  0.999349         0.996681               0.999634   0.999269
#                    8  0.999292         0.996402               0.999602   0.999205
#                    9  0.99938          0.996848               0.999651   0.999304
# Cophenetic Correlation Coefficient: 0.840498604634
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.994151         0.375028               0.997062   0.994151
#                    3  0.991367         0.524198               0.995643   0.991357
#                    4  0.991022         0.591665               0.995463   0.99099
#                    5  0.990324         0.733073               0.995081   0.990215
#                    6  0.986757         0.70181                0.993245   0.986562
#                    7  0.990674         0.836429               0.995207   0.99046
#                    8  0.991093         0.862102               0.9954     0.990841
#                    9  0.993535         0.9113                 0.996642   0.99331
# Cophenetic Correlation Coefficient: 0.774513476078
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.996196         0.711614               0.998087   0.996196
#                    3  0.991533         0.671809               0.995709   0.991491
#                    4  0.991953         0.705492               0.995923   0.991892
#                    5  0.989759         0.663059               0.994811   0.989688
#                    6  0.985727         0.589884               0.992764   0.985626
#                    7  0.980038         0.501373               0.989868   0.979888
#                    8  0.97231          0.408901               0.985919   0.972084
#                    9  0.982664         0.765836               0.991003   0.982246
# Cophenetic Correlation Coefficient: 0.610786371567
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.991819         0.582918               0.995872   0.991818
#                    3  0.991047         0.61681                0.995482   0.991008
#                    4  0.990127         0.598729               0.995015   0.990085
#                    5  0.988762         0.575173               0.994324   0.988718
#                    6  0.98252          0.481142               0.991152   0.98246
#                    7  0.971836         0.357574               0.985711   0.971738
#                    8  0.960479         0.236433               0.979911   0.960322
#                    9  0.995583         0.949878               0.997696   0.995458
# Cophenetic Correlation Coefficient: 0.629534222303
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.988528         0.446327               0.99421    0.988527
#                    3  0.989855         0.603268               0.994879   0.989812
#                    4  0.989386         0.597299               0.99464    0.98934
#                    5  0.988047         0.574614               0.993961   0.987999
#                    6  0.98267          0.490324               0.99123    0.982612
#                    7  0.972774         0.367764               0.986189   0.972677
#                    8  0.959409         0.227553               0.979367   0.959247
#                    9  0.996739         0.960533               0.998308   0.996669
# Cophenetic Correlation Coefficient: 0.632452105299
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.980543         0.258158               0.990163   0.980542
#                    3  0.983046         0.764488               0.991255   0.982704
#                    4  0.994841         0.93481                0.997321   0.994704
#                    5  0.997527         0.972003               0.998707   0.997434
#                    6  0.997512         0.971841               0.998699   0.997418
#                    7  0.997591         0.974129               0.998738   0.997495
#                    8  0.997653         0.97572                0.998768   0.997553
#                    9  0.998327         0.984015               0.999118   0.998246
# Cophenetic Correlation Coefficient: 0.689765559643
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.991008         0.668303               0.995436   0.990958
#                    3  0.982682         0.716487               0.99109    0.98235
#                    4  0.984866         0.851033               0.992012   0.984349
#                    5  0.991673         0.93392                0.99556    0.991194
#                    6  0.991667         0.933854               0.995557   0.991188
#                    7  0.991645         0.933631               0.995545   0.991164
#                    8  0.991597         0.933202               0.995519   0.991114
#                    9  0.991539         0.932747               0.995489   0.991052
# Cophenetic Correlation Coefficient: 0.752916902249
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.977892         0.206086               0.98879    0.977891
#                    3  0.974456         0.701648               0.98668    0.973796
#                    4  0.964095         0.680584               0.98092    0.962709
#                    5  0.983691         0.8834                 0.991221   0.982611
#                    6  0.983937         0.885821               0.991344   0.982852
#                    7  0.983925         0.885751               0.991338   0.982839
#                    8  0.983881         0.885476               0.991313   0.982791
#                    9  0.98384          0.885251               0.99129    0.982747
# Cophenetic Correlation Coefficient: 0.807957853994
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.969313         0.48358                0.984347   0.969114
#                    3  0.990254         0.891525               0.994889   0.989859
#                    4  0.97898          0.843427               0.988732   0.977777
#                    5  0.987285         0.913011               0.993104   0.986359
#                    6  0.988748         0.926514               0.993861   0.987831
#                    7  0.988655         0.926444               0.993806   0.987722
#                    8  0.988634         0.926307               0.993794   0.987699
#                    9  0.988593         0.926059               0.993772   0.987655
# Cophenetic Correlation Coefficient: 0.826111004367
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.983875         0.692756               0.991718   0.983568
#                    3  0.990257         0.8947                 0.994892   0.989852
#                    4  0.981855         0.826137               0.990424   0.981054
#                    5  0.970301         0.777554               0.98403    0.968636
#                    6  0.978461         0.856188               0.988312   0.976931
#                    7  0.979618         0.874602               0.988879   0.977985
#                    8  0.979319         0.87624                0.988695   0.977627
#                    9  0.979292         0.876077               0.988681   0.977598
# Cophenetic Correlation Coefficient: 0.837333710252
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.984945         0.732012               0.992244   0.984614
#                    3  0.991792         0.905368               0.995705   0.991466
#                    4  0.98394          0.847677               0.991526   0.983217
#                    5  0.974407         0.792525               0.986416   0.973168
#                    6  0.960904         0.707211               0.979193   0.959006
#                    7  0.978482         0.872891               0.988201   0.976769
#                    8  0.985112         0.919092               0.991735   0.983656
#                    9  0.985385         0.920794               0.991883   0.983946
