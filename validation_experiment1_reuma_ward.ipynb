# %% [markdown]
# # Validation of Experiment 1 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from temporal_reuma import main_algorithm
from encoder_sequence import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
#read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/bio_corrente_sequence.csv',sep = ';')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'ward'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,10)}
    for k in range(2,10):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,10):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,10):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,10), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.66590848749
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.66590848749
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.66590848749
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.66590848749
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.66590848749
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.66590848749
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993287         0.816867               0.996589   0.993198
#                    6  0.991514         0.819652               0.995666   0.991361
#                    7  0.989776         0.823522               0.994749   0.989538
#                    8  0.988122         0.825011               0.993869   0.987789
#                    9  0.9866           0.827371               0.993048   0.986161
# Cophenetic Correlation Coefficient: 0.319518199054
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.64619          0.164678               0.769642   0.628345
#                    3  0.633667         0.265789               0.669334   0.515284
#                    4  0.84153          0.662259               0.790028   0.664171
#                    5  0.867064         0.678739               0.774225   0.634486
#                    6  0.882413         0.701454               0.783662   0.649221
#                    7  0.886567         0.703529               0.781336   0.648131
#                    8  0.891966         0.704228               0.776455   0.643754
#                    9  0.889616         0.68955                0.76301    0.623929
# Cophenetic Correlation Coefficient: 0.257123542793
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.818034         0.635253               0.868306   0.793898
#                    3  0.899365         0.798919               0.894494   0.84508
#                    4  0.994281         0.986456               0.990566   0.982073
#                    5  0.970767         0.927765               0.94932    0.904455
#                    6  0.958098         0.888281               0.917462   0.853212
#                    7  0.956647         0.869387               0.899162   0.828454
#                    8  0.970266         0.886516               0.904255   0.8335
#                    9  0.955093         0.807151               0.834264   0.72009
# Cophenetic Correlation Coefficient: 0.217452072822
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.993375         0.986463               0.992284   0.985954
#                    4  0.964277         0.92086                0.948175   0.919851
#                    5  0.994459         0.98423                0.987822   0.977291
#                    6  0.993634         0.981577               0.985748   0.973489
#                    7  0.969321         0.899295               0.91822    0.85901
#                    8  0.983101         0.935547               0.945645   0.90039
#                    9  0.958999         0.824517               0.849675   0.741324
# Cophenetic Correlation Coefficient: 0.305550560619
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999849         0.999698               0.999849   0.999701
#                    3  0.952964         0.903713               0.944833   0.899797
#                    4  0.998867         0.997572               0.998475   0.996967
#                    5  0.9627           0.909554               0.938771   0.891013
#                    6  0.992952         0.979719               0.984284   0.970602
#                    7  0.971012         0.909416               0.928428   0.871646
#                    8  0.965806         0.879371               0.900497   0.827516
#                    9  0.982479         0.928651               0.939098   0.888956
# Cophenetic Correlation Coefficient: 0.323912828468
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99303          0.986045               0.993988   0.990638
#                    3  0.975921         0.950938               0.972349   0.948531
#                    4  0.97117          0.939927               0.964259   0.932679
#                    5  0.944564         0.876406               0.920027   0.867411
#                    6  0.974782         0.933849               0.951761   0.913169
#                    7  0.987457         0.963612               0.972018   0.947453
#                    8  0.95526          0.853687               0.881671   0.797262
#                    9  0.976262         0.91047                0.924827   0.86448
# Cophenetic Correlation Coefficient: 0.476175226507
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999346         0.998692               0.999349   0.998706
#                    3  0.986625         0.972512               0.984071   0.970893
#                    4  0.998377         0.996531               0.997831   0.995697
#                    5  0.994857         0.988627               0.992735   0.986257
#                    6  0.907324         0.780501               0.853096   0.749519
#                    7  0.993937         0.981845               0.985698   0.973366
#                    8  0.984639         0.951799               0.962415   0.929924
#                    9  0.967582         0.887608               0.908337   0.838621
# Cophenetic Correlation Coefficient: 0.537854397157
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999723         0.999447               0.999724   0.999452
#                    3  0.990473         0.980361               0.988531   0.978904
#                    4  0.998319         0.996417               0.997771   0.995604
#                    5  0.996421         0.992264               0.995099   0.990347
#                    6  0.994283         0.986739               0.991288   0.984736
#                    7  0.994083         0.982283               0.986043   0.974046
#                    8  0.9921           0.975885               0.981069   0.964767
#                    9  0.976339         0.924334               0.941062   0.890215
# Cophenetic Correlation Coefficient: 0.578628610187
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99343          0.98646                0.992098   0.985441
#                    4  0.998713         0.99726                0.998299   0.996652
#                    5  0.996011         0.99137                0.994529   0.989233
#                    6  0.998904         0.997503               0.998373   0.996968
#                    7  0.974066         0.934414               0.954583   0.91877
#                    8  0.99391          0.981691               0.985574   0.9731
#                    9  0.98749          0.96087                0.969474   0.942926
# Cophenetic Correlation Coefficient: 0.605116409678
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.993776         0.987136               0.992439   0.985969
#                    4  0.998167         0.99609                0.997564   0.995236
#                    5  0.995364         0.989975               0.993646   0.987501
#                    6  0.999405         0.998703               0.999167   0.998338
#                    7  0.927004         0.822111               0.880695   0.788745
#                    8  0.994025         0.982064               0.985856   0.973621
#                    9  0.99154          0.973999               0.979632   0.961921
# Cophenetic Correlation Coefficient: 0.622412104625
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.993621         0.986787               0.992199   0.985467
#                    4  0.997833         0.995375               0.997117   0.994363
#                    5  0.994642         0.988418               0.992662   0.985562
#                    6  0.999324         0.998527               0.999053   0.99811
#                    7  0.959791         0.904105               0.9367     0.887886
#                    8  0.983018         0.955564               0.968348   0.942953
#                    9  0.994105         0.982227               0.985981   0.973902
# Cophenetic Correlation Coefficient: 0.638819023287
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.993106         0.985735               0.991596   0.984357
#                    4  0.997658         0.995009               0.996897   0.993952
#                    5  0.993018         0.984885               0.990409   0.981136
#                    6  0.99922          0.9983                 0.998907   0.99782
#                    7  0.977444         0.946534               0.964815   0.937541
#                    8  0.955297         0.888941               0.924189   0.86542
#                    9  0.994083         0.982182               0.985934   0.97378
# Cophenetic Correlation Coefficient: 0.655785545915
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.98943          0.97813                0.987113   0.976144
#                    4  0.997275         0.994184               0.996373   0.99291
#                    5  0.991725         0.982061               0.988581   0.977543
#                    6  0.998849         0.997489               0.998384   0.996781
#                    7  0.991322         0.979511               0.98651    0.97575
#                    8  0.924694         0.819781               0.88076    0.789403
#                    9  0.988236         0.967524               0.975895   0.956016
# Cophenetic Correlation Coefficient: 0.668002583574
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.982357         0.963472               0.978448   0.960128
#                    4  0.997372         0.994394               0.996508   0.993144
#                    5  0.993754         0.986467               0.991389   0.983066
#                    6  0.998678         0.997117               0.998146   0.996307
#                    7  0.996909         0.992866               0.995321   0.99124
#                    8  0.963168         0.912291               0.942105   0.897446
#                    9  0.962144         0.904794               0.934386   0.883559
# Cophenetic Correlation Coefficient: 0.675976190734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998189         0.996378               0.998203   0.996602
#                    3  0.972561         0.943014               0.966129   0.937211
#                    4  0.997365         0.994368               0.996477   0.993086
#                    5  0.995313         0.989853               0.993547   0.987296
#                    6  0.998366         0.996433               0.997703   0.995429
#                    7  0.997705         0.994867               0.996665   0.993557
#                    8  0.983957         0.961907               0.974847   0.955124
#                    9  0.920383         0.808949               0.873328   0.776889
# Cophenetic Correlation Coefficient: 0.680327355816
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.994498         0.988996               0.994578   0.990097
#                    3  0.965546         0.928479               0.957509   0.921266
#                    4  0.997129         0.99385                0.996142   0.992406
#                    5  0.996203         0.991775               0.994764   0.98968
#                    6  0.997965         0.995554               0.997135   0.994304
#                    7  0.997993         0.995604               0.997158   0.994337
#                    8  0.991163         0.979201               0.986289   0.975245
#                    9  0.940443         0.857363               0.905533   0.833583
