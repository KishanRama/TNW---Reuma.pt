# %% [markdown]
# # Validation of Experiment 2 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, cophenet, fcluster
from fastcluster import linkage
from temporal_reuma_das import main_algorithm
from encoder_sequence_das import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
### read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/das28_sequence.csv',sep = ';',decimal=',')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
        results.loc[results['score'] == float('inf'), 'score'] = 100
        results.loc[results['score'] == float('-inf'), 'score'] = 100

    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'single'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,20)}
    for k in range(2,20):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,20):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,20):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,20), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.803534722734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.999875         0.992                  0.999937   0.999875
#                    5  0.999374         0.972                  0.999685   0.999374
#                    6  0.995124         0.836                  0.997543   0.995124
#                    7  0.987037         0.62                   0.993461   0.987037
#                    8  0.972036         0.276                  0.985877   0.972036
#                    9  0.961885         0.072                  0.980737   0.961885
#                   10  1                1                      1          1
#                   11  1                1                      1          1
#                   12  0.999778         0.997186               0.999886   0.999775
#                   13  0.999288         0.992327               0.99963    0.999269
#                   14  0.997624         0.976936               0.998758   0.997547
#                   15  0.99484          0.95283                0.997296   0.994661
#                   16  0.989945         0.91322                0.994713   0.989568
#                   17  0.981134         0.843331               0.990071   0.980439
#                   18  0.969856         0.761314               0.984085   0.968663
#                   19  0.957996         0.678993               0.977772   0.956261
# Cophenetic Correlation Coefficient: 0.803534722734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.999875         0.992                  0.999937   0.999875
#                    5  0.999374         0.972                  0.999685   0.999374
#                    6  0.995124         0.836                  0.997543   0.995124
#                    7  0.987037         0.62                   0.993461   0.987037
#                    8  0.972036         0.276                  0.985877   0.972036
#                    9  0.961885         0.072                  0.980737   0.961885
#                   10  1                1                      1          1
#                   11  1                1                      1          1
#                   12  0.999778         0.997186               0.999886   0.999775
#                   13  0.999288         0.992327               0.99963    0.999269
#                   14  0.997624         0.976936               0.998758   0.997547
#                   15  0.99484          0.95283                0.997296   0.994661
#                   16  0.989945         0.91322                0.994713   0.989568
#                   17  0.981134         0.843331               0.990071   0.980439
#                   18  0.969856         0.761314               0.984085   0.968663
#                   19  0.957996         0.678993               0.977772   0.956261
# Cophenetic Correlation Coefficient: 0.803534722734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.999875         0.992                  0.999937   0.999875
#                    5  0.999374         0.972                  0.999685   0.999374
#                    6  0.995124         0.836                  0.997543   0.995124
#                    7  0.987037         0.62                   0.993461   0.987037
#                    8  0.972036         0.276                  0.985877   0.972036
#                    9  0.961885         0.072                  0.980737   0.961885
#                   10  1                1                      1          1
#                   11  1                1                      1          1
#                   12  0.999778         0.997186               0.999886   0.999775
#                   13  0.999288         0.992327               0.99963    0.999269
#                   14  0.997624         0.976936               0.998758   0.997547
#                   15  0.99484          0.95283                0.997296   0.994661
#                   16  0.989945         0.91322                0.994713   0.989568
#                   17  0.981134         0.843331               0.990071   0.980439
#                   18  0.969856         0.761314               0.984085   0.968663
#                   19  0.957996         0.678993               0.977772   0.956261
# Cophenetic Correlation Coefficient: 0.803534722734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.999875         0.992                  0.999937   0.999875
#                    5  0.999374         0.972                  0.999685   0.999374
#                    6  0.995124         0.836                  0.997543   0.995124
#                    7  0.987037         0.62                   0.993461   0.987037
#                    8  0.972036         0.276                  0.985877   0.972036
#                    9  0.961885         0.072                  0.980737   0.961885
#                   10  1                1                      1          1
#                   11  1                1                      1          1
#                   12  0.999778         0.997186               0.999886   0.999775
#                   13  0.999288         0.992327               0.99963    0.999269
#                   14  0.997624         0.976936               0.998758   0.997547
#                   15  0.99484          0.95283                0.997296   0.994661
#                   16  0.989945         0.91322                0.994713   0.989568
#                   17  0.981134         0.843331               0.990071   0.980439
#                   18  0.969856         0.761314               0.984085   0.968663
#                   19  0.957996         0.678993               0.977772   0.956261
# Cophenetic Correlation Coefficient: 0.803534722734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.999875         0.992                  0.999937   0.999875
#                    5  0.999374         0.972                  0.999685   0.999374
#                    6  0.995124         0.836                  0.997543   0.995124
#                    7  0.987037         0.62                   0.993461   0.987037
#                    8  0.972036         0.276                  0.985877   0.972036
#                    9  0.961885         0.072                  0.980737   0.961885
#                   10  1                1                      1          1
#                   11  1                1                      1          1
#                   12  0.999778         0.997186               0.999886   0.999775
#                   13  0.999288         0.992327               0.99963    0.999269
#                   14  0.997624         0.976936               0.998758   0.997547
#                   15  0.99484          0.95283                0.997296   0.994661
#                   16  0.989945         0.91322                0.994713   0.989568
#                   17  0.981134         0.843331               0.990071   0.980439
#                   18  0.969856         0.761314               0.984085   0.968663
#                   19  0.957996         0.678993               0.977772   0.956261
# Cophenetic Correlation Coefficient: 0.803534722734
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.999875         0.992                  0.999937   0.999875
#                    5  0.999374         0.972                  0.999685   0.999374
#                    6  0.995124         0.836                  0.997543   0.995124
#                    7  0.987037         0.62                   0.993461   0.987037
#                    8  0.972036         0.276                  0.985877   0.972036
#                    9  0.961885         0.072                  0.980737   0.961885
#                   10  1                1                      1          1
#                   11  1                1                      1          1
#                   12  0.999778         0.997186               0.999886   0.999775
#                   13  0.999288         0.992327               0.99963    0.999269
#                   14  0.997624         0.976936               0.998758   0.997547
#                   15  0.99484          0.95283                0.997296   0.994661
#                   16  0.989945         0.91322                0.994713   0.989568
#                   17  0.981134         0.843331               0.990071   0.980439
#                   18  0.969856         0.761314               0.984085   0.968663
#                   19  0.957996         0.678993               0.977772   0.956261
# Cophenetic Correlation Coefficient: 0.818295296558
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999346         0.896                  0.999672   0.999346
#                    3  0.993569         0.436                  0.996775   0.993569
#                    4  0.999023         0.931943               0.999508   0.999023
#                    5  0.99808          0.925788               0.999027   0.998077
#                    6  0.994719         0.861735               0.997317   0.994688
#                    7  0.990019         0.778574               0.994921   0.98992
#                    8  0.979719         0.607469               0.989655   0.979467
#                    9  0.970048         0.483266               0.984692   0.969647
#                   10  0.990253         0.887897               0.99492    0.989894
#                   11  0.983641         0.826534               0.991448   0.983005
#                   12  0.976246         0.764974               0.987546   0.97528
#                   13  0.968609         0.708497               0.983501   0.967293
#                   14  0.979629         0.839785               0.98913    0.978422
#                   15  0.978715         0.843717               0.988584   0.977345
#                   16  0.977275         0.843299               0.987751   0.975704
#                   17  0.975892         0.843519               0.986936   0.974086
#                   18  0.974783         0.845412               0.98626    0.972747
#                   19  0.96883          0.815402               0.982977   0.966275
# Cophenetic Correlation Coefficient: 0.844002590449
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999346         0.896                  0.999672   0.999346
#                    3  0.993569         0.436                  0.996775   0.993569
#                    4  0.998998         0.931943               0.999496   0.998998
#                    5  0.99803          0.925788               0.999002   0.998027
#                    6  0.99462          0.860422               0.997267   0.994588
#                    7  0.989226         0.770003               0.994516   0.989119
#                    8  0.977471         0.586898               0.988502   0.977192
#                    9  0.96655          0.455123               0.982891   0.966102
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984499         0.843046               0.991862   0.98381
#                   12  0.982537         0.83867                0.990785   0.98168
#                   13  0.979987         0.830642               0.989377   0.978909
#                   14  0.978639         0.832923               0.988596   0.97737
#                   15  0.977945         0.838852               0.988166   0.97652
#                   16  0.976894         0.841548               0.987538   0.975278
#                   17  0.975632         0.842409               0.986788   0.973795
#                   18  0.974402         0.843194               0.986049   0.972334
#                   19  0.973104         0.843233               0.985268   0.97079
# Cophenetic Correlation Coefficient: 0.863128499609
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999346         0.896                  0.999672   0.999346
#                    3  0.993569         0.436                  0.996775   0.993569
#                    4  0.998998         0.931943               0.999496   0.998998
#                    5  0.99803          0.925788               0.999002   0.998027
#                    6  0.99462          0.860422               0.997267   0.994588
#                    7  0.989226         0.770003               0.994516   0.989119
#                    8  0.977471         0.586898               0.988502   0.977192
#                    9  0.966575         0.455235               0.982904   0.966127
#                   10  0.986323         0.846235               0.992858   0.985783
#                   11  0.982941         0.827928               0.991037   0.982199
#                   12  0.981235         0.828185               0.990084   0.980325
#                   13  0.979853         0.830203               0.989297   0.978777
#                   14  0.978741         0.833903               0.988647   0.977483
#                   15  0.978            0.839565               0.988191   0.976585
#                   16  0.976751         0.840618               0.987459   0.975126
#                   17  0.975393         0.840901               0.986657   0.973541
#                   18  0.974259         0.842363               0.98597    0.972179
#                   19  0.97301          0.84272                0.985215   0.970688
# Cophenetic Correlation Coefficient: 0.859241150248
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999346         0.896                  0.999672   0.999346
#                    3  0.993569         0.436                  0.996775   0.993569
#                    4  0.998998         0.931943               0.999496   0.998998
#                    5  0.99803          0.925788               0.999002   0.998027
#                    6  0.99462          0.860422               0.997267   0.994588
#                    7  0.989226         0.770003               0.994516   0.989119
#                    8  0.977471         0.586898               0.988502   0.977192
#                    9  0.966575         0.455235               0.982904   0.966127
#                   10  0.986323         0.846235               0.992858   0.985783
#                   11  0.982892         0.827585               0.991011   0.982149
#                   12  0.981284         0.828643               0.99011    0.980374
#                   13  0.980119         0.832592               0.989439   0.97905
#                   14  0.978645         0.833421               0.988595   0.977379
#                   15  0.978096         0.840323               0.988242   0.97668
#                   16  0.976799         0.841004               0.987485   0.975174
#                   17  0.975585         0.842213               0.986761   0.973738
#                   18  0.974449         0.843532               0.986074   0.972379
#                   19  0.973104         0.843274               0.985267   0.970787
# Cophenetic Correlation Coefficient: 0.278254945725
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.99995          0.996                  0.999975   0.99995
#                    4  0.99985          0.992                  0.999924   0.99985
#                    5  0.999299         0.972                  0.999647   0.999299
#                    6  0.994875         0.836                  0.997417   0.994875
#                    7  0.985773         0.62                   0.992819   0.985773
#                    8  0.968427         0.276                  0.984038   0.968427
#                    9  0.953824         0.072                  0.976617   0.953824
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984669         0.844562               0.991952   0.983986
#                   12  0.983292         0.844937               0.991185   0.982467
#                   13  0.982047         0.846639               0.990477   0.981064
#                   14  0.981369         0.852605               0.990061   0.980241
#                   15  0.981055         0.859839               0.989841   0.979804
#                   16  0.981032         0.867764               0.989779   0.97969
#                   17  0.980117         0.869036               0.989238   0.978631
#                   18  0.978538         0.866445               0.988326   0.976838
#                   19  0.976208         0.860243               0.986984   0.974193
# Cophenetic Correlation Coefficient: 0.714989866792
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999875         0.992                  0.999937   0.999875
#                    3  1                0.999997               1          1
#                    4  0.999975         0.999181               0.999987   0.999974
#                    5  0.999924         0.998039               0.999961   0.999923
#                    6  0.999737         0.99473                0.999865   0.999731
#                    7  0.99869          0.979153               0.999325   0.998653
#                    8  0.995983         0.945989               0.997917   0.99585
#                    9  0.990936         0.89163                0.995281   0.990604
#                   10  0.984548         0.832271               0.991927   0.983946
#                   11  0.982339         0.826553               0.990724   0.981565
#                   12  0.979258         0.8171                 0.989042   0.978244
#                   13  0.976293         0.809122               0.987404   0.975014
#                   14  0.9768           0.833614               0.987556   0.975325
#                   15  0.973908         0.824617               0.985923   0.972097
#                   16  0.972043         0.823053               0.984824   0.969918
#                   17  0.9676           0.799534               0.982383   0.965099
#                   18  0.968533         0.812017               0.982821   0.965959
#                   19  0.987036         0.929629               0.992816   0.985719
# Cophenetic Correlation Coefficient: 0.574337248761
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99985          0.988                  0.999925   0.99985
#                    3  0.999778         0.995975               0.999887   0.999778
#                    4  0.999926         0.998658               0.999961   0.999923
#                    5  0.999875         0.997515               0.999935   0.999871
#                    6  0.999688         0.994206               0.99984    0.99968
#                    7  0.998519         0.977655               0.999236   0.998477
#                    8  0.995496         0.941506               0.997663   0.995348
#                    9  0.990038         0.88441                0.994811   0.989677
#                   10  0.981507         0.811449               0.990322   0.980796
#                   11  0.975744         0.783792               0.987225   0.974696
#                   12  0.969261         0.755756               0.983697   0.96775
#                   13  0.96349          0.7341                 0.980507   0.96147
#                   14  0.968601         0.79592                0.983013   0.966356
#                   15  0.96918          0.807532               0.983243   0.966794
#                   16  0.993722         0.964855               0.99652    0.993061
#                   17  0.992414         0.957543               0.995798   0.991626
#                   18  0.994487         0.968957               0.996957   0.993945
#                   19  0.990847         0.950541               0.994929   0.989922
# Cophenetic Correlation Coefficient: 0.42454980775
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999825         0.984                  0.999912   0.999825
#                    3  0.99958          0.991953               0.999786   0.99958
#                    4  0.999926         0.998658               0.999961   0.999923
#                    5  0.999875         0.997515               0.999935   0.999871
#                    6  0.999565         0.993001               0.999777   0.999556
#                    7  0.99847          0.977239               0.99921    0.998427
#                    8  0.995423         0.941074               0.997626   0.995274
#                    9  0.989822         0.883475               0.994697   0.989456
#                   10  0.980763         0.807573               0.989929   0.980032
#                   11  0.973567         0.772154               0.986065   0.972434
#                   12  0.964947         0.733514               0.981379   0.963233
#                   13  0.956309         0.697033               0.976623   0.953887
#                   14  0.96059          0.75485                0.978629   0.957766
#                   15  0.982725         0.907116               0.990402   0.980929
#                   16  0.990612         0.951484               0.994745   0.989534
#                   17  0.993297         0.965783               0.996243   0.992518
#                   18  0.991312         0.956093               0.995127   0.990303
#                   19  0.988557         0.942597               0.993584   0.987242
# Cophenetic Correlation Coefficient: 0.288674446759
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999825         0.984                  0.999912   0.999825
#                    3  0.99958          0.991953               0.999786   0.99958
#                    4  0.999507         0.993597               0.999743   0.999486
#                    5  0.999432         0.992216               0.999704   0.999409
#                    6  0.999245         0.988999               0.999608   0.999218
#                    7  0.998054         0.972407               0.998993   0.997993
#                    8  0.995279         0.938929               0.99755    0.995121
#                    9  0.989753         0.882807               0.99466    0.989382
#                   10  0.982688         0.819729               0.990947   0.982023
#                   11  0.977333         0.794639               0.988068   0.976354
#                   12  0.969898         0.76242                0.984035   0.968437
#                   13  0.961677         0.728849               0.97952    0.959586
#                   14  0.955059         0.707                  0.975825   0.952344
#                   15  0.958353         0.755385               0.977283   0.955163
#                   16  0.979121         0.893031               0.988333   0.976879
#                   17  0.987179         0.93698                0.992782   0.985655
#                   18  0.985577         0.929544               0.991876   0.983855
#                   19  0.987924         0.942032               0.99318    0.986443
# Cophenetic Correlation Coefficient: 0.176478014585
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999825         0.984                  0.999912   0.999825
#                    3  0.999083         0.978564               0.999535   0.999082
#                    4  0.998598         0.983385               0.999266   0.998538
#                    5  0.997102         0.967753               0.998479   0.996964
#                    6  0.996854         0.965346               0.998348   0.996704
#                    7  0.996374         0.959287               0.9981     0.996211
#                    8  0.995131         0.944607               0.997453   0.994923
#                    9  0.991554         0.908305               0.995581   0.991205
#                   10  0.985936         0.858631               0.992624   0.985344
#                   11  0.977946         0.797829               0.988392   0.976983
#                   12  0.971832         0.773718               0.985071   0.970467
#                   13  0.963502         0.738111               0.980508   0.961524
#                   14  0.95534          0.7089                 0.975981   0.952669
#                   15  0.955566         0.7421                 0.975754   0.952209
#                   16  0.971724         0.856694               0.984192   0.968787
#                   17  0.978312         0.896008               0.987762   0.975759
#                   18  0.980468         0.908736               0.988934   0.978048
#                   19  0.982904         0.922282               0.990272   0.980683
# Cophenetic Correlation Coefficient: 0.104294909658
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999699         0.964                  0.999849   0.999699
#                    3  0.997873         0.954454               0.998919   0.997872
#                    4  0.99764          0.972544               0.998765   0.997537
#                    5  0.993751         0.934096               0.996715   0.993452
#                    6  0.991991         0.918302               0.995786   0.991606
#                    7  0.991349         0.9124                 0.995447   0.990933
#                    8  0.990316         0.901374               0.994908   0.989864
#                    9  0.987907         0.877298               0.993648   0.987362
#                   10  0.983802         0.841148               0.991488   0.983085
#                   11  0.977541         0.793134               0.988174   0.976538
#                   12  0.973551         0.78158                0.985992   0.972257
#                   13  0.966537         0.752999               0.982145   0.964721
#                   14  0.959953         0.731664               0.978494   0.957584
#                   15  0.959591         0.761878               0.977982   0.956605
#                   16  0.953545         0.745958               0.974511   0.949806
#                   17  0.947612         0.731759               0.971065   0.943086
#                   18  0.96418          0.838306               0.979716   0.959948
#                   19  0.964851         0.850126               0.979897   0.960295
# Cophenetic Correlation Coefficient: 0.104483464897
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999222         0.916                  0.99961    0.999222
#                    3  0.994565         0.886047               0.997232   0.994563
#                    4  0.996409         0.954682               0.998127   0.996276
#                    5  0.993173         0.931181               0.996397   0.992836
#                    6  0.992323         0.925932               0.995944   0.99193
#                    7  0.991691         0.922162               0.995606   0.991252
#                    8  0.990677         0.913212               0.995072   0.990194
#                    9  0.989183         0.898641               0.994289   0.988638
#                   10  0.986366         0.873895               0.992804   0.985694
#                   11  0.981602         0.836726               0.990281   0.980704
#                   12  0.975119         0.792041               0.986825   0.973891
#                   13  0.969724         0.773319               0.983856   0.968083
#                   14  0.962884         0.750647               0.980067   0.960689
#                   15  0.955451         0.727466               0.975912   0.952586
#                   16  0.94622          0.697813               0.970711   0.942466
#                   17  0.94565          0.724652               0.969963   0.940999
#                   18  0.958421         0.814981               0.976423   0.953553
#                   19  0.957756         0.824151               0.975782   0.952282
# Cophenetic Correlation Coefficient: 0.132594032109
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999021         0.892                  0.999509   0.999021
#                    3  0.99326          0.861825               0.996564   0.993258
#                    4  0.994519         0.930529               0.997142   0.994332
#                    5  0.99112          0.910922               0.995314   0.990682
#                    6  0.988531         0.898095               0.993908   0.987905
#                    7  0.988303         0.904078               0.993754   0.987601
#                    8  0.986697         0.895529               0.992884   0.985867
#                    9  0.985945         0.891588               0.992479   0.985057
#                   10  0.984501         0.881093               0.991711   0.983539
#                   11  0.981932         0.862657               0.990341   0.980834
#                   12  0.977432         0.832227               0.987935   0.976088
#                   13  0.971217         0.794442               0.984591   0.969511
#                   14  0.962577         0.747735               0.97991    0.960341
#                   15  0.956286         0.728761               0.976367   0.953448
#                   16  0.961579         0.792127               0.978849   0.958314
#                   17  0.953975         0.768891               0.974484   0.949818
#                   18  0.952165         0.781566               0.973076   0.94707
#                   19  0.945129         0.763267               0.968894   0.938924
# Cophenetic Correlation Coefficient: 0.166298421239
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998695         0.879064               0.999344   0.998694
#                    3  0.9889           0.668638               0.994391   0.988894
#                    4  0.990025         0.841764               0.994871   0.989888
#                    5  0.989366         0.891913               0.99439    0.988863
#                    6  0.986798         0.882127               0.992992   0.986085
#                    7  0.982601         0.859752               0.990712   0.981573
#                    8  0.979101         0.856729               0.988663   0.977655
#                    9  0.977764         0.859381               0.987843   0.976032
#                   10  0.979855         0.880675               0.988911   0.978097
#                   11  0.979529         0.883134               0.988708   0.977675
#                   12  0.979195         0.883163               0.98852    0.977263
#                   13  0.977758         0.876517               0.987727   0.975675
#                   14  0.975408         0.865092               0.986425   0.973114
#                   15  0.971458         0.846488               0.984235   0.968818
#                   16  0.966212         0.822663               0.981315   0.963101
#                   17  0.958708         0.790156               0.977113   0.954895
#                   18  0.950567         0.763852               0.972418   0.945776
#                   19  0.949104         0.776953               0.971177   0.943396
# Cophenetic Correlation Coefficient: 0.175430339745
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.996611         0.656033               0.998297   0.99661
#                    3  0.991072         0.579864               0.995497   0.991055
#                    4  0.970693         0.516717               0.98495    0.970475
#                    5  0.979004         0.747334               0.989032   0.978437
#                    6  0.977738         0.784395               0.988225   0.976781
#                    7  0.975796         0.802909               0.987074   0.974465
#                    8  0.971097         0.803291               0.984307   0.969191
#                    9  0.966693         0.807355               0.981603   0.964077
#                   10  0.973341         0.852945               0.985188   0.970977
#                   11  0.974092         0.86675                0.985477   0.97146
#                   12  0.973504         0.870873               0.985046   0.970539
#                   13  0.971703         0.868356               0.983937   0.968352
#                   14  0.967148         0.853146               0.981295   0.963132
#                   15  0.963402         0.846903               0.978866   0.958506
#                   16  0.957369         0.837693               0.974794   0.951035
#                   17  0.964311         0.869905               0.978689   0.958526
#                   18  0.969335         0.890786               0.981603   0.964024
#                   19  0.973357         0.906853               0.983972   0.968479
