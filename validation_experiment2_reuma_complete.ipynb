# %% [markdown]
# # Validation of Experiment 2 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, cophenet, fcluster
from fastcluster import linkage
from temporal_reuma_das import main_algorithm
from encoder_sequence_das import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
### read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/das28_sequence.csv',sep = ';',decimal=',')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
        results.loc[results['score'] == float('inf'), 'score'] = 100
        results.loc[results['score'] == float('-inf'), 'score'] = 100

    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'complete'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,20)}
    for k in range(2,20):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,20):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,20):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,20), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.80356317295
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999498         0.972                  0.999748   0.999498
#                    5  0.995969         0.836                  0.997972   0.995969
#                    6  0.988374         0.62                   0.994142   0.988374
#                    7  0.974159         0.276                  0.986961   0.974159
#                    8  0.96314          0.072                  0.981379   0.96314
#                    9  0.995901         0.944731               0.997869   0.995746
#                   10  1                1                      1          1
#                   11  0.999802         0.997291               0.999899   0.9998
#                   12  0.99936          0.992791               0.999668   0.999344
#                   13  0.997841         0.978202               0.998874   0.997773
#                   14  0.995178         0.954649               0.997476   0.995011
#                   15  0.990498         0.916026               0.995009   0.990144
#                   16  0.981972         0.84703                0.99052    0.981309
#                   17  0.970955         0.766199               0.984677   0.969811
#                   18  0.959067         0.683462               0.978352   0.957382
#                   19  0.947157         0.60438                0.971996   0.944908
# Cophenetic Correlation Coefficient: 0.80356317295
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999498         0.972                  0.999748   0.999498
#                    5  0.995969         0.836                  0.997972   0.995969
#                    6  0.988374         0.62                   0.994142   0.988374
#                    7  0.974159         0.276                  0.986961   0.974159
#                    8  0.96314          0.072                  0.981379   0.96314
#                    9  0.995901         0.944731               0.997869   0.995746
#                   10  1                1                      1          1
#                   11  0.999802         0.997291               0.999899   0.9998
#                   12  0.99936          0.992791               0.999668   0.999344
#                   13  0.997841         0.978202               0.998874   0.997773
#                   14  0.995178         0.954649               0.997476   0.995011
#                   15  0.990498         0.916026               0.995009   0.990144
#                   16  0.981972         0.84703                0.99052    0.981309
#                   17  0.970955         0.766199               0.984677   0.969811
#                   18  0.959067         0.683462               0.978352   0.957382
#                   19  0.947157         0.60438                0.971996   0.944908
# Cophenetic Correlation Coefficient: 0.80356317295
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999498         0.972                  0.999748   0.999498
#                    5  0.995969         0.836                  0.997972   0.995969
#                    6  0.988374         0.62                   0.994142   0.988374
#                    7  0.974159         0.276                  0.986961   0.974159
#                    8  0.96314          0.072                  0.981379   0.96314
#                    9  0.995901         0.944731               0.997869   0.995746
#                   10  1                1                      1          1
#                   11  0.999802         0.997291               0.999899   0.9998
#                   12  0.99936          0.992791               0.999668   0.999344
#                   13  0.997841         0.978202               0.998874   0.997773
#                   14  0.995178         0.954649               0.997476   0.995011
#                   15  0.990498         0.916026               0.995009   0.990144
#                   16  0.981972         0.84703                0.99052    0.981309
#                   17  0.970955         0.766199               0.984677   0.969811
#                   18  0.959067         0.683462               0.978352   0.957382
#                   19  0.947157         0.60438                0.971996   0.944908
# Cophenetic Correlation Coefficient: 0.80356317295
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999498         0.972                  0.999748   0.999498
#                    5  0.995969         0.836                  0.997972   0.995969
#                    6  0.988374         0.62                   0.994142   0.988374
#                    7  0.974159         0.276                  0.986961   0.974159
#                    8  0.96314          0.072                  0.981379   0.96314
#                    9  0.995901         0.944731               0.997869   0.995746
#                   10  1                1                      1          1
#                   11  0.999802         0.997291               0.999899   0.9998
#                   12  0.99936          0.992791               0.999668   0.999344
#                   13  0.997841         0.978202               0.998874   0.997773
#                   14  0.995178         0.954649               0.997476   0.995011
#                   15  0.990498         0.916026               0.995009   0.990144
#                   16  0.981972         0.84703                0.99052    0.981309
#                   17  0.970955         0.766199               0.984677   0.969811
#                   18  0.959067         0.683462               0.978352   0.957382
#                   19  0.947157         0.60438                0.971996   0.944908
# Cophenetic Correlation Coefficient: 0.80356317295
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999498         0.972                  0.999748   0.999498
#                    5  0.995969         0.836                  0.997972   0.995969
#                    6  0.988374         0.62                   0.994142   0.988374
#                    7  0.974159         0.276                  0.986961   0.974159
#                    8  0.96314          0.072                  0.981379   0.96314
#                    9  0.995901         0.944731               0.997869   0.995746
#                   10  1                1                      1          1
#                   11  0.999802         0.997291               0.999899   0.9998
#                   12  0.99936          0.992791               0.999668   0.999344
#                   13  0.997841         0.978202               0.998874   0.997773
#                   14  0.995178         0.954649               0.997476   0.995011
#                   15  0.990498         0.916026               0.995009   0.990144
#                   16  0.981972         0.84703                0.99052    0.981309
#                   17  0.970955         0.766199               0.984677   0.969811
#                   18  0.959067         0.683462               0.978352   0.957382
#                   19  0.947157         0.60438                0.971996   0.944908
# Cophenetic Correlation Coefficient: 0.80356317295
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999498         0.972                  0.999748   0.999498
#                    5  0.995969         0.836                  0.997972   0.995969
#                    6  0.988374         0.62                   0.994142   0.988374
#                    7  0.974159         0.276                  0.986961   0.974159
#                    8  0.96314          0.072                  0.981379   0.96314
#                    9  0.995901         0.944731               0.997869   0.995746
#                   10  1                1                      1          1
#                   11  0.999802         0.997291               0.999899   0.9998
#                   12  0.99936          0.992791               0.999668   0.999344
#                   13  0.997841         0.978202               0.998874   0.997773
#                   14  0.995178         0.954649               0.997476   0.995011
#                   15  0.990498         0.916026               0.995009   0.990144
#                   16  0.981972         0.84703                0.99052    0.981309
#                   17  0.970955         0.766199               0.984677   0.969811
#                   18  0.959067         0.683462               0.978352   0.957382
#                   19  0.947157         0.60438                0.971996   0.944908
# Cophenetic Correlation Coefficient: 0.783346194276
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999975         0.996                  0.999987   0.999975
#                    3  0.9999           0.992                  0.99995    0.9999
#                    4  0.999674         0.984333               0.999836   0.999673
#                    5  0.997328         0.921887               0.998646   0.997306
#                    6  0.992368         0.816669               0.996122   0.99229
#                    7  0.982109         0.638541               0.990881   0.98189
#                    8  0.968827         0.486889               0.984054   0.968427
#                    9  0.979668         0.790542               0.989387   0.978987
#                   10  0.971623         0.74248                0.985079   0.970478
#                   11  0.962871         0.677246               0.980423   0.961278
#                   12  0.988778         0.92338                0.993908   0.988015
#                   13  0.986942         0.912979               0.992906   0.985997
#                   14  0.982778         0.8895                 0.990627   0.981452
#                   15  0.978077         0.863935               0.988049   0.976333
#                   16  0.973262         0.839072               0.985408   0.971126
#                   17  0.967681         0.812348               0.982331   0.965087
#                   18  0.982852         0.913111               0.990476   0.981188
#                   19  0.9739           0.872569               0.985435   0.971253
# Cophenetic Correlation Coefficient: 0.6710167802
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.666812         0.133544               0.771291   0.63097
#                    3  0.670023         0.160966               0.770399   0.629991
#                    4  0.670034         0.161088               0.770394   0.629985
#                    5  0.670217         0.162111               0.770434   0.630044
#                    6  0.670673         0.16729                0.77009    0.629662
#                    7  0.671556         0.17404                0.769964   0.629525
#                    8  0.67149          0.184681               0.767729   0.62682
#                    9  0.670522         0.197608               0.764008   0.622281
#                   10  0.681847         0.25092                0.766966   0.62648
#                   11  0.677692         0.262652               0.758645   0.616173
#                   12  0.679767         0.283033               0.756376   0.613298
#                   13  0.680482         0.299087               0.751927   0.60758
#                   14  0.681723         0.304742               0.752003   0.607417
#                   15  0.679942         0.308566               0.748552   0.602974
#                   16  0.678318         0.311205               0.745585   0.598933
#                   17  0.676458         0.313216               0.742616   0.594924
#                   18  0.678838         0.323784               0.742149   0.594473
#                   19  0.676749         0.327471               0.73802    0.58905
# Cophenetic Correlation Coefficient: 0.622030654757
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.678236         0.34702                0.724031   0.570087
#                    3  0.687355         0.369888               0.719802   0.564836
#                    4  0.687233         0.369652               0.719623   0.564611
#                    5  0.687887         0.371091               0.719651   0.56476
#                    6  0.687757         0.37098                0.718663   0.563638
#                    7  0.687566         0.371243               0.715384   0.55983
#                    8  0.68532          0.367131               0.711085   0.554029
#                    9  0.686485         0.370885               0.70365    0.544366
#                   10  0.690735         0.380876               0.698665   0.537138
#                   11  0.74322          0.483716               0.722657   0.568123
#                   12  0.757846         0.509232               0.726042   0.572282
#                   13  0.763996         0.519469               0.726312   0.571653
#                   14  0.787521         0.5606                 0.740161   0.589842
#                   15  0.788619         0.561888               0.739451   0.588431
#                   16  0.80348          0.587625               0.749573   0.602554
#                   17  0.803235         0.586484               0.74821    0.600527
#                   18  0.802103         0.583639               0.745939   0.597287
#                   19  0.801494         0.581598               0.743815   0.594352
# Cophenetic Correlation Coefficient: 0.573602399079
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.601605         0.168592               0.70161    0.536912
#                    3  0.570563         0.209465               0.659893   0.467366
#                    4  0.746801         0.470627               0.680522   0.518111
#                    5  0.747557         0.471687               0.680564   0.518187
#                    6  0.747516         0.471498               0.680332   0.517891
#                    7  0.747428         0.470861               0.679457   0.51676
#                    8  0.747142         0.469486               0.677746   0.514647
#                    9  0.747017         0.467795               0.675115   0.511345
#                   10  0.747423         0.466731               0.672413   0.50782
#                   11  0.755939         0.481164               0.677849   0.513963
#                   12  0.785955         0.527778               0.692565   0.531496
#                   13  0.790654         0.534928               0.695142   0.534167
#                   14  0.797183         0.545286               0.699363   0.538866
#                   15  0.798201         0.545958               0.69876    0.537924
#                   16  0.801462         0.550952               0.700579   0.5401
#                   17  0.804673         0.555751               0.702258   0.542151
#                   18  0.803538         0.552255               0.699311   0.538614
#                   19  0.803765         0.551149               0.697556   0.536551
# Cophenetic Correlation Coefficient: 0.138807891423
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.699783         0.415931               0.76534    0.605908
#                    4  0.813742         0.623902               0.791925   0.655496
#                    5  0.813079         0.622494               0.79087    0.653969
#                    6  0.800607         0.596093               0.771479   0.625391
#                    7  0.820317         0.620124               0.76625    0.619506
#                    8  0.831211         0.630465               0.762084   0.615748
#                    9  0.843479         0.653167               0.773782   0.63227
#                   10  0.8454           0.655201               0.773513   0.632513
#                   11  0.845499         0.655325               0.773546   0.632502
#                   12  0.845276         0.65472                0.773074   0.63185
#                   13  0.844538         0.652678               0.771497   0.629632
#                   14  0.841802         0.645534               0.766158   0.622147
#                   15  0.837387         0.633998               0.757487   0.610079
#                   16  0.832579         0.620736               0.747258   0.595561
#                   17  0.827164         0.605409               0.735348   0.578887
#                   18  0.824836         0.597639               0.728955   0.569569
#                   19  0.847784         0.637627               0.749249   0.597841
# Cophenetic Correlation Coefficient: 0.616051555927
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.568978         0.110695               0.638314   0.47841
#                    3  0.763133         0.489476               0.67592    0.512543
#                    4  0.782737         0.488275               0.645225   0.478245
#                    5  0.798036         0.482598               0.620816   0.451974
#                    6  0.812067         0.492113               0.617924   0.447394
#                    7  0.824812         0.500261               0.615504   0.444204
#                    8  0.834151         0.504473               0.612304   0.440453
#                    9  0.837023         0.502456               0.608458   0.435051
#                   10  0.84058          0.504676               0.608623   0.434111
#                   11  0.850768         0.429932               0.519933   0.350293
#                   12  0.853731         0.432004               0.519626   0.350514
#                   13  0.855802         0.433522               0.519542   0.350762
#                   14  0.858642         0.434516               0.518556   0.349883
#                   15  0.861343         0.436973               0.519089   0.350586
#                   16  0.862977         0.437722               0.518766   0.350313
#                   17  0.864201         0.438723               0.518906   0.350518
#                   18  0.864999         0.439891               0.519582   0.351091
#                   19  0.867638         0.445563               0.523637   0.354774
# Cophenetic Correlation Coefficient: 0.460416417487
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.628244         0.256106               0.685814   0.518442
#                    3  0.716425         0.430247               0.68097    0.518147
#                    4  0.784356         0.513739               0.67565    0.512857
#                    5  0.798702         0.472332               0.608414   0.439764
#                    6  0.813028         0.464717               0.586195   0.416626
#                    7  0.852559         0.503222               0.593808   0.424418
#                    8  0.860864         0.50079                0.585042   0.415419
#                    9  0.86515          0.479432               0.560047   0.390242
#                   10  0.87612          0.443232               0.515168   0.347012
#                   11  0.881534         0.44428                0.512369   0.344977
#                   12  0.88603          0.446709               0.511839   0.344631
#                   13  0.889957         0.445758               0.508344   0.341582
#                   14  0.892946         0.446648               0.507434   0.340687
#                   15  0.895299         0.446197               0.505752   0.338873
#                   16  0.901781         0.447926               0.503134   0.33661
#                   17  0.904118         0.448232               0.5022     0.335584
#                   18  0.905606         0.447831               0.501148   0.334371
#                   19  0.910789         0.448399               0.498163   0.332353
# Cophenetic Correlation Coefficient: 0.392444955086
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.605857         0.189308               0.686707   0.51559
#                    3  0.676065         0.352611               0.671302   0.506844
#                    4  0.742414         0.449888               0.656197   0.492018
#                    5  0.753961         0.377864               0.546898   0.375103
#                    6  0.788602         0.383447               0.519376   0.350956
#                    7  0.822446         0.39973                0.508629   0.341577
#                    8  0.851659         0.426281               0.51485    0.346583
#                    9  0.859853         0.423308               0.505348   0.339005
#                   10  0.867891         0.422775               0.499409   0.333585
#                   11  0.871111         0.40141                0.476039   0.312074
#                   12  0.881834         0.388044               0.454958   0.294588
#                   13  0.893776         0.38882                0.447859   0.289008
#                   14  0.898555         0.387877               0.444088   0.285738
#                   15  0.910566         0.398699               0.447729   0.288799
#                   16  0.91634          0.404003               0.449719   0.290462
#                   17  0.922645         0.413173               0.455518   0.295042
#                   18  0.926058         0.416081               0.456458   0.29586
#                   19  0.928948         0.415746               0.454492   0.2942
# Cophenetic Correlation Coefficient: 0.515330137861
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.758804         0.405212               0.829725   0.722081
#                    3  0.685534         0.381827               0.670353   0.50112
#                    4  0.758852         0.485945               0.678119   0.513682
#                    5  0.777497         0.492105               0.657682   0.491471
#                    6  0.77384          0.380068               0.529427   0.359571
#                    7  0.802657         0.385896               0.51006    0.342449
#                    8  0.813448         0.377049               0.491985   0.325922
#                    9  0.826096         0.364496               0.469474   0.305779
#                   10  0.836583         0.350986               0.44828    0.287329
#                   11  0.858147         0.363312               0.445557   0.286403
#                   12  0.868798         0.367052               0.442997   0.28346
#                   13  0.881368         0.361034               0.42808    0.272114
#                   14  0.896813         0.367658               0.42459    0.270013
#                   15  0.90084          0.369429               0.424093   0.269464
#                   16  0.903416         0.361205               0.414544   0.261506
#                   17  0.912982         0.365832               0.413076   0.260845
#                   18  0.920365         0.372756               0.415688   0.262925
#                   19  0.92456          0.37678                0.417324   0.264262
# Cophenetic Correlation Coefficient: 0.498590152703
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.765033         0.305664               0.859598   0.753928
#                    3  0.632966         0.268451               0.631492   0.462083
#                    4  0.685365         0.350193               0.617447   0.4494
#                    5  0.719834         0.374746               0.587308   0.416867
#                    6  0.735914         0.369488               0.558508   0.385965
#                    7  0.790965         0.387842               0.52229    0.353454
#                    8  0.817802         0.415095               0.528736   0.360222
#                    9  0.828242         0.413696               0.519413   0.35077
#                   10  0.840107         0.420047               0.51819    0.347744
#                   11  0.853468         0.399991               0.487108   0.320943
#                   12  0.867931         0.411552               0.488927   0.322875
#                   13  0.889424         0.424239               0.486604   0.322592
#                   14  0.893431         0.420858               0.480861   0.31727
#                   15  0.896377         0.416668               0.475426   0.311776
#                   16  0.908535         0.418155               0.468627   0.30671
#                   17  0.916619         0.421888               0.46744    0.305874
#                   18  0.919587         0.420109               0.463975   0.302797
#                   19  0.924529         0.422906               0.463978   0.302732
# Cophenetic Correlation Coefficient: 0.43109531333
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.554227        0.0723081               0.665601   0.488761
#                    3  0.603269        0.207949                0.602554   0.432931
#                    4  0.669517        0.326985                0.618498   0.449968
#                    5  0.736688        0.413829                0.614027   0.445228
#                    6  0.745464        0.392137                0.574452   0.404164
#                    7  0.793118        0.397886                0.532198   0.359447
#                    8  0.815187        0.415571                0.53183    0.362423
#                    9  0.829301        0.422144                0.527065   0.358989
#                   10  0.836223        0.4169                  0.51653    0.348663
#                   11  0.850799        0.42273                 0.512318   0.344077
#                   12  0.866537        0.433304                0.51198    0.343945
#                   13  0.871755        0.43233                 0.508344   0.339333
#                   14  0.90285         0.47232                 0.527317   0.358528
#                   15  0.910441        0.482114                0.532373   0.363481
#                   16  0.914863        0.486289                0.533615   0.365025
#                   17  0.918098        0.486368                0.531878   0.363341
#                   18  0.920879        0.486221                0.530399   0.361738
#                   19  0.924183        0.482006                0.524238   0.356029
# Cophenetic Correlation Coefficient: 0.522187508882
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.774278         0.403112               0.849842   0.742536
#                    3  0.67552          0.345762               0.702008   0.543306
#                    4  0.705107         0.404178               0.672138   0.508367
#                    5  0.716749         0.419574               0.659456   0.491461
#                    6  0.750929         0.384615               0.558101   0.384045
#                    7  0.779742         0.413332               0.561259   0.389095
#                    8  0.801583         0.399665               0.525869   0.356844
#                    9  0.816308         0.411391               0.526199   0.357597
#                   10  0.845804         0.430266               0.523304   0.354341
#                   11  0.865079         0.460825               0.540997   0.371352
#                   12  0.871492         0.446928               0.522024   0.353996
#                   13  0.885009         0.46131                0.527621   0.359122
#                   14  0.890028         0.459369               0.522191   0.354525
#                   15  0.897115         0.463011               0.521349   0.353841
#                   16  0.899926         0.460723               0.51771    0.350007
#                   17  0.902344         0.455975               0.512005   0.343983
#                   18  0.904394         0.450548               0.506193   0.337317
#                   19  0.908358         0.448555               0.501795   0.333586
# Cophenetic Correlation Coefficient: 0.527321907626
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.821021         0.348455               0.898756   0.818233
#                    3  0.635211         0.268283               0.659603   0.49277
#                    4  0.695014         0.38637                0.669678   0.505917
#                    5  0.744421         0.437611               0.632369   0.458785
#                    6  0.772935         0.466897               0.632      0.461565
#                    7  0.792812         0.48244                0.6274     0.456552
#                    8  0.808733         0.491573               0.621502   0.448954
#                    9  0.813043         0.481535               0.607124   0.431568
#                   10  0.830108         0.492396               0.603775   0.428938
#                   11  0.86249          0.490114               0.573017   0.401985
#                   12  0.868697         0.486618               0.564863   0.39429
#                   13  0.872933         0.474646               0.549762   0.379392
#                   14  0.874874         0.464251               0.538496   0.367626
#                   15  0.890327         0.462985               0.525712   0.357305
#                   16  0.898223         0.471588               0.529336   0.360954
#                   17  0.901671         0.47217                0.528091   0.359513
#                   18  0.910958         0.489674               0.539787   0.370908
#                   19  0.914414         0.492558               0.541045   0.371737
# Cophenetic Correlation Coefficient: 0.552281465793
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.858595         0.41606                0.920586   0.856536
#                    3  0.723527         0.407634               0.791278   0.653466
#                    4  0.707924         0.415084               0.692128   0.532093
#                    5  0.7513           0.484374               0.694604   0.536878
#                    6  0.769659         0.501365               0.681685   0.522289
#                    7  0.767113         0.480007               0.654778   0.482107
#                    8  0.824298         0.506518               0.622358   0.451225
#                    9  0.839642         0.524672               0.628336   0.458014
#                   10  0.859239         0.545661               0.634147   0.465193
#                   11  0.863899         0.539204               0.624131   0.454036
#                   12  0.8765           0.521466               0.595303   0.425087
#                   13  0.878789         0.514399               0.586571   0.416054
#                   14  0.883669         0.507525               0.576406   0.405394
#                   15  0.886166         0.498869               0.566668   0.394472
#                   16  0.889729         0.491427               0.556984   0.384939
#                   17  0.908889         0.525788               0.577753   0.407258
#                   18  0.910898         0.520796               0.571924   0.400843
#                   19  0.91234          0.515609               0.566614   0.394711
# Cophenetic Correlation Coefficient: 0.55088480213
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.796165         0.352411               0.881271   0.790701
#                    3  0.651761         0.309405               0.687179   0.520387
#                    4  0.693194         0.391767               0.67838    0.511879
#                    5  0.71575          0.412562               0.65438    0.489158
#                    6  0.739708         0.432937               0.636164   0.468455
#                    7  0.79919          0.494389               0.634021   0.461324
#                    8  0.828043         0.527553               0.642712   0.471972
#                    9  0.841528         0.536536               0.639535   0.470914
#                   10  0.851075         0.541396               0.636497   0.467842
#                   11  0.859987         0.543314               0.631711   0.462279
#                   12  0.861908         0.535176               0.622949   0.450919
#                   13  0.888473         0.54124                0.607794   0.436384
#                   14  0.893247         0.544694               0.607594   0.436952
#                   15  0.897282         0.547065               0.607388   0.436715
#                   16  0.900545         0.546779               0.605435   0.434234
#                   17  0.907905         0.548264               0.601513   0.431381
#                   18  0.910296         0.54051                0.592176   0.422001
#                   19  0.916041         0.540374               0.588298   0.418785
