# %% [markdown]
# # Validation of Experiment 2 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, cophenet, fcluster
from fastcluster import linkage
from temporal_reuma_das import main_algorithm
from encoder_sequence_das import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
### read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/das28_sequence.csv',sep = ';',decimal=',')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
        results.loc[results['score'] == float('inf'), 'score'] = 100
        results.loc[results['score'] == float('-inf'), 'score'] = 100

    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'ward'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,20)}
    for k in range(2,20):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,20):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,20):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,20), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.804037535346
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804037535346
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804037535346
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804037535346
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804037535346
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804037535346
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.166333201568
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.776877         0.532082               0.816266   0.704281
#                    3  0.666637         0.354723               0.647729   0.467705
#                    4  0.665734         0.351942               0.64432    0.464202
#                    5  0.666139         0.351569               0.64222    0.462045
#                    6  0.668536         0.354917               0.64255    0.462633
#                    7  0.671029         0.358579               0.642904   0.463138
#                    8  0.67405          0.362962               0.643797   0.464438
#                    9  0.678323         0.369123               0.645098   0.466764
#                   10  0.684852         0.37834                0.646985   0.469799
#                   11  0.689943         0.38553                0.64837    0.472245
#                   12  0.692603         0.389239               0.64872    0.472813
#                   13  0.693641         0.389828               0.647587   0.4718
#                   14  0.695696         0.392442               0.647459   0.471751
#                   15  0.697805         0.395132               0.647409   0.471832
#                   16  0.698729         0.395405               0.646091   0.470628
#                   17  0.699845         0.395894               0.644763   0.469396
#                   18  0.70227          0.398884               0.644654   0.469416
#                   19  0.704507         0.401444               0.644271   0.469116
# Cophenetic Correlation Coefficient: 0.159161585196
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.810534         0.593725               0.853085   0.746424
#                    3  0.766184         0.496228               0.680802   0.52071
#                    4  0.805049         0.53214                0.671106   0.508499
#                    5  0.817959         0.52724                0.651059   0.485437
#                    6  0.809645         0.425873               0.548778   0.373562
#                    7  0.82067          0.433476               0.547736   0.373022
#                    8  0.828574         0.440693               0.548821   0.374711
#                    9  0.83294          0.441788               0.546615   0.372689
#                   10  0.836745         0.446467               0.548535   0.374736
#                   11  0.839866         0.450579               0.550354   0.376815
#                   12  0.840945         0.452016               0.550993   0.377549
#                   13  0.840929         0.451644               0.550613   0.377164
#                   14  0.841148         0.451828               0.550615   0.377211
#                   15  0.841597         0.452126               0.550502   0.377235
#                   16  0.841915         0.452238               0.550334   0.377163
#                   17  0.843272         0.453068               0.550003   0.377242
#                   18  0.843889         0.452853               0.549217   0.376663
#                   19  0.845228         0.45424                0.549535   0.377181
# Cophenetic Correlation Coefficient: 0.0990522668229
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.750049         0.483483               0.793947   0.670837
#                    3  0.735941         0.434974               0.64508    0.483405
#                    4  0.807378         0.525752               0.660459   0.495831
#                    5  0.830271         0.516487               0.626701   0.459291
#                    6  0.8368           0.452503               0.552981   0.383377
#                    7  0.850475         0.450239               0.539878   0.371409
#                    8  0.869232         0.460932               0.537831   0.368148
#                    9  0.878749         0.473805               0.544146   0.374761
#                   10  0.884269         0.465335               0.531909   0.363087
#                   11  0.894409         0.477988               0.538622   0.36871
#                   12  0.900262         0.486153               0.543307   0.372911
#                   13  0.903803         0.492397               0.547191   0.376891
#                   14  0.908026         0.501277               0.553391   0.383078
#                   15  0.91307          0.509685               0.559181   0.388143
#                   16  0.914976         0.513344               0.561572   0.390611
#                   17  0.916134         0.514891               0.56233    0.391478
#                   18  0.916987         0.516329               0.563249   0.39234
#                   19  0.921221         0.518237               0.564088   0.391435
# Cophenetic Correlation Coefficient: 0.34294849979
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.742121         0.480661               0.765657   0.630329
#                    3  0.744371         0.478511               0.697474   0.546889
#                    4  0.771577         0.473859               0.641555   0.476224
#                    5  0.814819         0.473258               0.593395   0.424484
#                    6  0.852366         0.516172               0.607347   0.438596
#                    7  0.874032         0.525518               0.600474   0.431394
#                    8  0.889615         0.518049               0.582306   0.411894
#                    9  0.899395         0.51948                0.577182   0.406911
#                   10  0.904348         0.509967               0.564105   0.39424
#                   11  0.910519         0.508705               0.558947   0.389034
#                   12  0.914392         0.501121               0.5489     0.379165
#                   13  0.920142         0.50953                0.553827   0.383974
#                   14  0.924069         0.515367               0.55721    0.387484
#                   15  0.927752         0.52089                0.560536   0.390684
#                   16  0.930391         0.525914               0.56403    0.394188
#                   17  0.9324           0.529831               0.566844   0.397034
#                   18  0.934297         0.533182               0.569146   0.399237
#                   19  0.935137         0.533418               0.569013   0.399001
# Cophenetic Correlation Coefficient: 0.198724867723
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.893216         0.722172               0.928882   0.868049
#                    3  0.786855         0.559785               0.741149   0.592181
#                    4  0.786882         0.553664               0.729853   0.576236
#                    5  0.784505         0.537809               0.709611   0.552447
#                    6  0.797982         0.541043               0.692129   0.531182
#                    7  0.798573         0.538125               0.687531   0.525835
#                    8  0.813501         0.558558               0.693428   0.53272
#                    9  0.823528         0.574171               0.700142   0.540907
#                   10  0.829424         0.581595               0.702103   0.543195
#                   11  0.830654         0.583426               0.702879   0.544078
#                   12  0.830904         0.583835               0.703064   0.544354
#                   13  0.831063         0.584099               0.703203   0.544482
#                   14  0.831259         0.583957               0.702859   0.543965
#                   15  0.832504         0.58509                0.702874   0.543671
#                   16  0.833312         0.584973               0.701956   0.542109
#                   17  0.834228         0.584048               0.699908   0.53944
#                   18  0.835006         0.58253                0.697305   0.536341
#                   19  0.836062         0.580858               0.694357   0.532555
# Cophenetic Correlation Coefficient: 0.360750519235
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.709841         0.419124               0.722399   0.573147
#                    3  0.762194         0.504234               0.70233    0.54607
#                    4  0.796664         0.525444               0.67338    0.514257
#                    5  0.817386         0.506014               0.627468   0.461001
#                    6  0.833542         0.475472               0.5796     0.409843
#                    7  0.878934         0.539788               0.611807   0.443029
#                    8  0.896649         0.553529               0.613635   0.44408
#                    9  0.903873         0.549418               0.604395   0.434806
#                   10  0.905555         0.528811               0.582291   0.412358
#                   11  0.90979          0.52485                0.575832   0.405775
#                   12  0.919791         0.530478               0.574926   0.405246
#                   13  0.92614          0.536197               0.576827   0.407156
#                   14  0.929501         0.525793               0.564288   0.394574
#                   15  0.934221         0.531975               0.56772    0.397943
#                   16  0.937386         0.52932                0.56321    0.393576
#                   17  0.940239         0.533233               0.565537   0.395883
#                   18  0.942829         0.538814               0.569859   0.399895
#                   19  0.945712         0.538208               0.567533   0.39761
# Cophenetic Correlation Coefficient: 0.544258599307
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.755847         0.510697               0.769009   0.645208
#                    3  0.785289         0.557082               0.739916   0.603428
#                    4  0.790709         0.513643               0.666514   0.507255
#                    5  0.850752         0.56965                0.666245   0.502729
#                    6  0.862074         0.549169               0.634373   0.468616
#                    7  0.884102         0.580692               0.650597   0.485557
#                    8  0.882409         0.526037               0.595385   0.425877
#                    9  0.884188         0.506322               0.57466    0.404048
#                   10  0.900484         0.509116               0.565548   0.395926
#                   11  0.910916         0.510075               0.559933   0.390336
#                   12  0.917119         0.518652               0.564635   0.395171
#                   13  0.92102          0.511614               0.555167   0.385815
#                   14  0.925028         0.507736               0.548879   0.37956
#                   15  0.92914          0.510346               0.549281   0.379687
#                   16  0.933947         0.510017               0.545932   0.376714
#                   17  0.935418         0.501137               0.536393   0.367393
#                   18  0.940544         0.505645               0.537661   0.368928
#                   19  0.943617         0.509566               0.539949   0.371032
# Cophenetic Correlation Coefficient: 0.433922577515
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.641183         0.273804               0.677143   0.518712
#                    3  0.728504         0.444503               0.680482   0.526661
#                    4  0.795545         0.53443                0.686438   0.530607
#                    5  0.851266         0.589832               0.687741   0.528701
#                    6  0.854838         0.537216               0.627652   0.460468
#                    7  0.883203         0.559149               0.628807   0.460259
#                    8  0.895536         0.562725               0.623713   0.455544
#                    9  0.898292         0.547264               0.605951   0.437363
#                   10  0.902516         0.541352               0.597395   0.42809
#                   11  0.905378         0.515221               0.56886    0.399298
#                   12  0.912292         0.510714               0.559798   0.390434
#                   13  0.919827         0.517335               0.56182    0.392334
#                   14  0.925784         0.501303               0.541887   0.373108
#                   15  0.93071          0.500986               0.538601   0.370084
#                   16  0.934628         0.503397               0.538706   0.370052
#                   17  0.938947         0.509623               0.542459   0.373531
#                   18  0.943282         0.516204               0.546568   0.377439
#                   19  0.945063         0.512494               0.541901   0.372971
# Cophenetic Correlation Coefficient: 0.526980452158
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.739438         0.477706               0.756681   0.62853
#                    3  0.765869         0.518047               0.718597   0.578584
#                    4  0.788083         0.484389               0.633487   0.467041
#                    5  0.851176         0.57185                0.668281   0.505544
#                    6  0.86429          0.557915               0.641992   0.476545
#                    7  0.884077         0.580336               0.650183   0.485353
#                    8  0.88649          0.56408                0.632197   0.46508
#                    9  0.895918         0.549835               0.610366   0.441632
#                   10  0.904828         0.525999               0.580382   0.410242
#                   11  0.910896         0.528421               0.578495   0.409179
#                   12  0.913768         0.516653               0.564724   0.395566
#                   13  0.916901         0.503031               0.549021   0.380341
#                   14  0.921669         0.49265                0.535599   0.367626
#                   15  0.93016          0.50519                0.543213   0.374586
#                   16  0.93434          0.510111               0.545669   0.377043
#                   17  0.939995         0.519901               0.552229   0.383193
#                   18  0.942551         0.519909               0.550783   0.381721
#                   19  0.945236         0.522639               0.552149   0.382695
# Cophenetic Correlation Coefficient: 0.521421512165
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.706098         0.411881               0.72813    0.584564
#                    3  0.760858         0.508761               0.714688   0.568048
#                    4  0.795579         0.532001               0.683272   0.52426
#                    5  0.842536         0.563789               0.66721    0.503421
#                    6  0.845782         0.519277               0.6162     0.4487
#                    7  0.868506         0.502881               0.58156    0.410879
#                    8  0.874466         0.495255               0.569068   0.399228
#                    9  0.881795         0.496756               0.565567   0.395558
#                   10  0.887297         0.48191                0.546666   0.377237
#                   11  0.897463         0.477471               0.535313   0.366512
#                   12  0.905615         0.474408               0.527001   0.358707
#                   13  0.91101          0.474573               0.523933   0.355901
#                   14  0.91538          0.469873               0.51661    0.349034
#                   15  0.919783         0.46343                0.50753    0.3408
#                   16  0.927758         0.475083               0.514331   0.347359
#                   17  0.93439          0.477401               0.512736   0.34602
#                   18  0.936768         0.477423               0.511413   0.344698
#                   19  0.941602         0.484542               0.51577    0.348734
# Cophenetic Correlation Coefficient: 0.500099632811
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.595333         0.189639               0.618771   0.454539
#                    3  0.717515         0.422505               0.668889   0.511304
#                    4  0.770192         0.476868               0.647462   0.485323
#                    5  0.778068         0.42767                0.578928   0.4071
#                    6  0.85001          0.516019               0.609116   0.441162
#                    7  0.862893         0.49064                0.572847   0.402303
#                    8  0.880936         0.503542               0.573911   0.402285
#                    9  0.888256         0.505835               0.570609   0.400184
#                   10  0.895061         0.508632               0.568695   0.39892
#                   11  0.898471         0.493367               0.550884   0.381827
#                   12  0.902288         0.484176               0.539318   0.370781
#                   13  0.91165          0.485361               0.534424   0.366012
#                   14  0.915458         0.459403               0.50591    0.339541
#                   15  0.922733         0.472321               0.514542   0.347478
#                   16  0.926151         0.472597               0.512784   0.345837
#                   17  0.931296         0.474346               0.511486   0.344621
#                   18  0.933766         0.474906               0.510842   0.343827
#                   19  0.936777         0.478788               0.513323   0.345693
# Cophenetic Correlation Coefficient: 0.51891071422
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.698421         0.396499               0.717305   0.576516
#                    3  0.76091          0.507988               0.712893   0.569466
#                    4  0.777394         0.484941               0.64811    0.484131
#                    5  0.84416          0.562703               0.66446    0.501148
#                    6  0.851871         0.516353               0.608081   0.438707
#                    7  0.873113         0.538313               0.614706   0.445501
#                    8  0.881692         0.535131               0.60506    0.435925
#                    9  0.886931         0.534096               0.600794   0.430334
#                   10  0.889978         0.513267               0.577487   0.406547
#                   11  0.892349         0.498081               0.56088    0.389637
#                   12  0.907521         0.504177               0.556116   0.386532
#                   13  0.91295          0.502777               0.551276   0.381903
#                   14  0.917823         0.498188               0.543639   0.374765
#                   15  0.920585         0.465356               0.508818   0.342049
#                   16  0.924168         0.468825               0.510204   0.343353
#                   17  0.926612         0.468924               0.509177   0.342058
#                   18  0.932275         0.472029               0.508754   0.341963
#                   19  0.936679         0.472712               0.506781   0.340395
# Cophenetic Correlation Coefficient: 0.491859156829
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.691847         0.382127               0.711285   0.569954
#                    3  0.738999         0.465716               0.692674   0.544397
#                    4  0.78265          0.478352               0.632538   0.471215
#                    5  0.833852         0.517385               0.624813   0.456065
#                    6  0.848694         0.519349               0.613757   0.445264
#                    7  0.861739         0.518251               0.602335   0.432904
#                    8  0.868871         0.511113               0.589805   0.419759
#                    9  0.883088         0.505228               0.573408   0.403086
#                   10  0.897908         0.526404               0.585018   0.414845
#                   11  0.904233         0.529271               0.58374    0.413912
#                   12  0.91212          0.512832               0.562443   0.391992
#                   13  0.918059         0.516621               0.562405   0.392168
#                   14  0.92132          0.51661                0.560114   0.390407
#                   15  0.92345          0.510113               0.552303   0.382943
#                   16  0.928826         0.508994               0.547888   0.378766
#                   17  0.932042         0.487291               0.524255   0.356194
#                   18  0.934641         0.487696               0.523025   0.355307
#                   19  0.938328         0.49238                0.525635   0.357712
# Cophenetic Correlation Coefficient: 0.540706060538
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.602383         0.198769               0.636024   0.478643
#                    3  0.665584         0.334616               0.642576   0.481685
#                    4  0.750114         0.433288               0.61882    0.451477
#                    5  0.825708         0.503534               0.61671    0.447045
#                    6  0.858326         0.538009               0.626174   0.457001
#                    7  0.869014         0.527211               0.606808   0.436225
#                    8  0.877114         0.520612               0.593495   0.423928
#                    9  0.884072         0.519941               0.587893   0.418515
#                   10  0.890055         0.518865               0.582899   0.413144
#                   11  0.898169         0.48959                0.547401   0.377677
#                   12  0.901282         0.477457               0.532985   0.364234
#                   13  0.907727         0.481369               0.532839   0.364097
#                   14  0.912914         0.478859               0.527128   0.358731
#                   15  0.924834         0.496298               0.538285   0.368424
#                   16  0.927825         0.495789               0.535389   0.366517
#                   17  0.930625         0.485912               0.523667   0.355755
#                   18  0.933417         0.48551                0.521556   0.353873
#                   19  0.934935         0.474854               0.509994   0.343258
# Cophenetic Correlation Coefficient: 0.500788355396
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.678554         0.356465               0.696153   0.548543
#                    3  0.775576         0.540095               0.7347     0.595061
#                    4  0.821781         0.565904               0.691488   0.534101
#                    5  0.849695         0.578327               0.676556   0.5155
#                    6  0.858297         0.539984               0.628367   0.460393
#                    7  0.872233         0.541105               0.618589   0.450032
#                    8  0.88131          0.547068               0.617786   0.449973
#                    9  0.88666          0.532512               0.598992   0.430361
#                   10  0.899908         0.533779               0.591465   0.421567
#                   11  0.906478         0.541182               0.59443    0.425141
#                   12  0.910586         0.543726               0.594417   0.425347
#                   13  0.915473         0.544069               0.591854   0.422456
#                   14  0.919154         0.533011               0.578304   0.40851
#                   15  0.921312         0.523424               0.567632   0.397511
#                   16  0.924258         0.481751               0.523253   0.355347
#                   17  0.928474         0.482194               0.521144   0.353487
#                   18  0.931598         0.4808                 0.517902   0.350385
#                   19  0.93366          0.478228               0.514297   0.346846
