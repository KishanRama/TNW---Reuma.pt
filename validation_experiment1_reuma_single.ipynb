# %% [markdown]
# # Validation of Experiment 1 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from temporal_reuma import main_algorithm
from encoder_sequence import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
#read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/bio_corrente_sequence.csv',sep = ';')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'single'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,10)}
    for k in range(2,10):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,10):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,10):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,10), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.658511652489
#   Number of clusters    Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  ------  ---------------  ---------------------  ---------
#                    2       1                1                      1          1
#                    3       1                1                      1          1
#                    4       1                1                      1          1
#                    5       1                1                      1          1
#                    6       1                1                      1          1
#                    7       1                1                      1          1
#                    8       1                1                      1          1
#                    9       1                1                      1          1
# Cophenetic Correlation Coefficient: 0.658511652489
#   Number of clusters    Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  ------  ---------------  ---------------------  ---------
#                    2       1                1                      1          1
#                    3       1                1                      1          1
#                    4       1                1                      1          1
#                    5       1                1                      1          1
#                    6       1                1                      1          1
#                    7       1                1                      1          1
#                    8       1                1                      1          1
#                    9       1                1                      1          1
# Cophenetic Correlation Coefficient: 0.658511652489
#   Number of clusters    Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  ------  ---------------  ---------------------  ---------
#                    2       1                1                      1          1
#                    3       1                1                      1          1
#                    4       1                1                      1          1
#                    5       1                1                      1          1
#                    6       1                1                      1          1
#                    7       1                1                      1          1
#                    8       1                1                      1          1
#                    9       1                1                      1          1
# Cophenetic Correlation Coefficient: 0.658511652489
#   Number of clusters    Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  ------  ---------------  ---------------------  ---------
#                    2       1                1                      1          1
#                    3       1                1                      1          1
#                    4       1                1                      1          1
#                    5       1                1                      1          1
#                    6       1                1                      1          1
#                    7       1                1                      1          1
#                    8       1                1                      1          1
#                    9       1                1                      1          1
# Cophenetic Correlation Coefficient: 0.658511652489
#   Number of clusters    Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  ------  ---------------  ---------------------  ---------
#                    2       1                1                      1          1
#                    3       1                1                      1          1
#                    4       1                1                      1          1
#                    5       1                1                      1          1
#                    6       1                1                      1          1
#                    7       1                1                      1          1
#                    8       1                1                      1          1
#                    9       1                1                      1          1
# Cophenetic Correlation Coefficient: 0.658511652489
#   Number of clusters    Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  ------  ---------------  ---------------------  ---------
#                    2       1                1                      1          1
#                    3       1                1                      1          1
#                    4       1                1                      1          1
#                    5       1                1                      1          1
#                    6       1                1                      1          1
#                    7       1                1                      1          1
#                    8       1                1                      1          1
#                    9       1                1                      1          1
# Cophenetic Correlation Coefficient: 0.713805102681
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999748         0.96                   0.999874   0.999748
#                    3  0.996082         0.688                  0.998035   0.996082
#                    4  0.98706          0.312                  0.993499   0.98706
#                    5  0.993438         0.824402               0.996663   0.993346
#                    6  0.991814         0.830167               0.995816   0.991659
#                    7  0.990473         0.837778               0.995104   0.990243
#                    8  0.988941         0.839544               0.994287   0.98862
#                    9  0.98717          0.836566               0.99334    0.986739
# Cophenetic Correlation Coefficient: 0.788691673405
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998239         0.72                   0.999118   0.998239
#                    3  0.996588         0.795139               0.998283   0.996572
#                    4  0.995096         0.820455               0.997519   0.99505
#                    5  0.993488         0.827821               0.996689   0.993396
#                    6  0.991715         0.828531               0.995765   0.991557
#                    7  0.990473         0.837778               0.995104   0.990243
#                    8  0.988941         0.839544               0.994287   0.98862
#                    9  0.987121         0.836015               0.993314   0.986688
# Cophenetic Correlation Coefficient: 0.838279142158
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998239         0.72                   0.999118   0.998239
#                    3  0.996588         0.795139               0.998283   0.996572
#                    4  0.995096         0.820455               0.997519   0.99505
#                    5  0.993488         0.827821               0.996689   0.993396
#                    6  0.991715         0.828531               0.995765   0.991557
#                    7  0.990473         0.837778               0.995104   0.990243
#                    8  0.988941         0.839544               0.994287   0.98862
#                    9  0.987121         0.836015               0.993314   0.986688
# Cophenetic Correlation Coefficient: 0.843294389625
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.997813         0.687895               0.998904   0.997813
#                    3  0.996038         0.771647               0.998004   0.996019
#                    4  0.993725         0.781464               0.996821   0.993662
#                    5  0.992296         0.802146               0.996078   0.992187
#                    6  0.99122          0.820093               0.99551    0.991052
#                    7  0.990276         0.83492                0.995002   0.99004
#                    8  0.988794         0.837689               0.99421    0.988467
#                    9  0.986974         0.834394               0.993237   0.986535
# Cophenetic Correlation Coefficient: 0.41095985263
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.983987         0.310365               0.991894   0.983984
#                    3  0.982254         0.560373               0.990937   0.982094
#                    4  0.986566         0.778332               0.993064   0.986297
#                    5  0.990095         0.853023               0.994872   0.989821
#                    6  0.988584         0.856358               0.994056   0.988205
#                    7  0.983515         0.812166               0.991406   0.98295
#                    8  0.976105         0.767658               0.98746    0.975163
#                    9  0.966442         0.710695               0.982264   0.964964
# Cophenetic Correlation Coefficient: 0.724013392342
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.999425         0.98306                0.999708   0.99942
#                    3  0.998372         0.974991               0.999158   0.998329
#                    4  0.992263         0.889414               0.995988   0.992038
#                    5  0.987674         0.84121                0.993601   0.987291
#                    6  0.98097          0.826417               0.98985    0.980283
#                    7  0.950046         0.812261               0.970549   0.947342
#                    8  0.80282          0.627557               0.872219   0.781224
#                    9  0.988574         0.97866                0.992098   0.986284
# Cophenetic Correlation Coefficient: 0.689988742227
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  1                1                      1          1
#                    3  0.994468         0.942751               0.997123   0.994326
#                    4  0.950691         0.906555               0.968794   0.946611
#                    5  0.999724         0.999443               0.999698   0.999398
#                    6  0.998042         0.996056               0.997873   0.995767
#                    7  0.996461         0.992873               0.99616    0.99236
#                    8  0.993776         0.987464               0.993246   0.986572
#                    9  0.999085         0.99815                0.998986   0.997992
# Cophenetic Correlation Coefficient: 0.666851154535
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99953          0.98791                0.999761   0.99953
#                    3  0.99914          0.993036               0.999544   0.999114
#                    4  0.994689         0.989939               0.996551   0.99412
#                    5  0.999598         0.999189               0.999562   0.999127
#                    6  0.997819         0.995608               0.997633   0.995286
#                    7  0.996219         0.992385               0.995897   0.991836
#                    8  0.993856         0.987626               0.993333   0.986741
#                    9  0.998368         0.996702               0.998194   0.996426
# Cophenetic Correlation Coefficient: 0.653611261599
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.99953          0.98791                0.999761   0.99953
#                    3  0.997361         0.976988               0.998609   0.997284
#                    4  0.98208          0.966129               0.988439   0.980286
#                    5  0.998618         0.997219               0.998504   0.997016
#                    6  0.99747          0.994907               0.997256   0.994533
#                    7  0.995744         0.991428               0.995382   0.990811
#                    8  0.993464         0.986834               0.992903   0.985891
#                    9  0.997179         0.994304               0.99689    0.993841
# Cophenetic Correlation Coefficient: 0.647826622385
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998961         0.971829               0.999472   0.998961
#                    3  0.993381         0.943112               0.996507   0.993186
#                    4  0.955173         0.915322               0.971052   0.950662
#                    5  0.998544         0.99707                0.998423   0.996854
#                    6  0.99747          0.994907               0.997256   0.994533
#                    7  0.995744         0.991428               0.995382   0.990811
#                    8  0.993454         0.986814               0.992892   0.985869
#                    9  0.997129         0.994203               0.996835   0.993732
# Cophenetic Correlation Coefficient: 0.652390910461
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.997724         0.939619               0.998843   0.997724
#                    3  0.983506         0.859153               0.991282   0.983012
#                    4  0.86853          0.751539               0.915125   0.855554
#                    5  0.998446         0.996873               0.998317   0.996643
#                    6  0.997336         0.994636               0.997111   0.994242
#                    7  0.995487         0.990912               0.995105   0.990257
#                    8  0.993311         0.986527               0.992736   0.985557
#                    9  0.995476         0.990871               0.99502    0.990162
# Cophenetic Correlation Coefficient: 0.664819309178
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.993791         0.834905               0.996843   0.993791
#                    3  0.980949         0.834857               0.989937   0.980386
#                    4  0.86853          0.751539               0.915125   0.855554
#                    5  0.997946         0.995865               0.997774   0.995562
#                    6  0.996245         0.992439               0.995927   0.991884
#                    7  0.994772         0.989468               0.994308   0.988685
#                    8  0.994011         0.987926               0.99345    0.987004
#                    9  0.992967         0.985819               0.992309   0.984729
# Cophenetic Correlation Coefficient: 0.676016991798
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.992577         0.79868                0.996226   0.992576
#                    3  0.980949         0.834857               0.989937   0.980386
#                    4  0.86853          0.751539               0.915125   0.855554
#                    5  0.996184         0.992317               0.995857   0.991755
#                    6  0.996584         0.993118               0.996274   0.992589
#                    7  0.996233         0.992408               0.995891   0.991816
#                    8  0.995265         0.990455               0.994827   0.989703
#                    9  0.99327          0.986427               0.99264    0.985368
# Cophenetic Correlation Coefficient: 0.684745018096
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.989365         0.718028               0.994589   0.989364
#                    3  0.980949         0.834857               0.989937   0.980386
#                    4  0.86853          0.751539               0.915125   0.855554
#                    5  0.995954         0.991854               0.995606   0.991254
#                    6  0.995965         0.99187                0.995597   0.991244
#                    7  0.998286         0.996543               0.998118   0.996251
#                    8  0.997708         0.995374               0.997481   0.99498
#                    9  0.996641         0.993219               0.996301   0.992636
# Cophenetic Correlation Coefficient: 0.691491682897
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.98929          0.714011               0.994552   0.989289
#                    3  0.980949         0.834857               0.989937   0.980386
#                    4  0.86853          0.751539               0.915125   0.855554
#                    5  0.995894         0.991734               0.995541   0.991126
#                    6  0.995344         0.990618               0.994922   0.989898
#                    7  0.998255         0.99648                0.998084   0.99618
#                    8  0.99703          0.994008               0.996736   0.993495
#                    9  0.995607         0.99113                0.995158   0.990362
