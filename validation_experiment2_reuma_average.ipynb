# %% [markdown]
# # Validation of Experiment 2 - Reuma.pt

# %%
#import libraries
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, cophenet, fcluster
from fastcluster import linkage
from temporal_reuma_das import main_algorithm
from encoder_sequence_das import encode
from validation_hc_wine import cluster_indices, cluster_external_index
from statistics import mean, stdev
from tabulate import tabulate
import pandas as pd
import numpy as np
import itertools
from matplotlib.backends.backend_pdf import PdfPages

# %%
#pre-defined scoring system
match=1.
mismatch=-1.1
#initialize pre-defined scoring dictionary
s = {'OO': match}
#get all combinations of letters
comb = list(itertools.product('ABCDEFGHIJZ',repeat = 2))

#gap penalty
gap_values = np.linspace(-1,1,21)
#gap_values = [0]

# %% [markdown]
# ## How many clusters?
# We perform the analysis for several values of gap penalty. In this script we vary the gap penalty from 0 to 1 with a 0.1 step.

# %%
### read .csv file
df = pd.read_csv('C:/Users/kisha_000/Desktop/tese/Temporal Needleman Wunsch/das28_sequence.csv',sep = ';',decimal=',')

#get the encoded sequences for each patient
df_encoded = encode(df)

for gap in gap_values:
    
    #sequence alignment results
    results = main_algorithm(df_encoded,gap,0)
    
    #reset indexes
    df_encoded = df_encoded.reset_index()
    
    ###############################################################################
    #       HIERARCHICAL CLUSTERING
    ###############################################################################
    #Convert the score matrix into a distance matrix by making all values positives
    if(gap == 0):
        results['score'] = 1/(results['score'])
        results.loc[results['score'] == float('inf'), 'score'] = 100
        results.loc[results['score'] == float('-inf'), 'score'] = 100

    else:
        results['score'] = 0 - results['score']
        results['score'] = results['score'] + abs(results['score'][results['score'].idxmin()])
    
    # distance metric used in hierarchical clustering
    method = 'average'
    
    Z = linkage(results['score'], method)
    
    # Cophenetic Correlation Coefficient
    c, coph_dists = cophenet(Z, results['score'])
    print('Cophenetic Correlation Coefficient:', c)
    
    
    ############################################################################
    #Compute Adjusted Wallace between cutoffs in the same dendrogram
    ############################################################################
    max_cutoff = round(Z[-1][2],1)
    cutoff_axis = np.linspace(0,max_cutoff,500)
    step = cutoff_axis[1] - cutoff_axis[0]
    adjusted_wallace_axis = []
    
    for cutoff in cutoff_axis:
        c_assignments_original_a = fcluster(Z,cutoff,criterion='distance')
        partition_original_a = cluster_indices(c_assignments_original_a,df_encoded.index.tolist())
        c_assignments_original_b = fcluster(Z,cutoff-step,criterion='distance')
        partition_original_b = cluster_indices(c_assignments_original_b,df_encoded.index.tolist())

        computed_indexes = cluster_external_index(partition_original_a,partition_original_b)
        #print(cutoff)
        adjusted_wallace_axis.append(computed_indexes[4])
        
    plt.figure(figsize=(25, 10))
    plt.subplot(1,2,1)
    plt.title('Adjusted Wallace between cutoffs')
    plt.plot(adjusted_wallace_axis, cutoff_axis)
    #plt.plot(cutoff_axis,adjusted_rand_axis)
    
    #plot the dendrogram at the side
    plt.subplot(1,2,2)
    plt.title('Hierarchical Clustering Dendrogram - gap: %.2f ' %gap)
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
            Z,
            #truncate_mode = 'lastp',
            #p=6,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            )
    plt.tight_layout()
    plt.show()
    
    
    ##############################################################################
    # HOW MANY CLUSTERS?
    ###############################################################################
    # bootstrap method - sampling without replacement
    np.random.seed(123)
    
    #dictionary to store all computed indexes for each number of clusters K=2,...9
    dicio_statistics = {k:{} for k in range(2,20)}
    for k in range(2,20):
        dicio_statistics[k]['rand'] = []
        dicio_statistics[k]['adjusted'] = []
        dicio_statistics[k]['FM'] = []
        dicio_statistics[k]['jaccard'] = []
    
    # number of bootstrap samples
    M = 250
    
    #for each bootstrap sample
    for i in range(M):
        # sampling rows of the original data
        idx = np.random.choice(len(df_encoded), int((3/4)*len(df_encoded)), replace = False)
        idx = np.sort(idx)
        #get all the possible combinations between the sampled patients
        patient_comb_bootstrap = list(itertools.combinations(df_encoded.loc[idx,'id_doente'],2))
        patient_comb_bootstrap = pd.DataFrame(patient_comb_bootstrap,columns = ['patient1','patient2'])
        #extract the scores regarding the previous sampled combinations to be used in hierarchical clustering
        results_bootstrap = pd.merge(results, patient_comb_bootstrap, how='inner', on=['patient1','patient2'])
        # Hierarchical Clustering of the bootstrap sample
        Z_bootstrap = linkage(results_bootstrap['score'],method)
        
        #for each number of clusters k=2,...,9
        for k in range(2,20):
            c_assignments_original = fcluster(Z,k,criterion='maxclust')
            c_assignments_bootstrap = fcluster(Z_bootstrap,k,criterion='maxclust')
            #list of clusters for the clustering result with the original data
            partition_original = cluster_indices(c_assignments_original,df_encoded.index.tolist())
            #list of clusters for the clustering result with the bootstrap sample
            partition_bootstrap = cluster_indices(c_assignments_bootstrap,idx)
            
            #compute 4 different cluster external indexes between the partitions
            computed_indexes = cluster_external_index(partition_original,partition_bootstrap)
            dicio_statistics[k]['rand'].append(computed_indexes[0])
            dicio_statistics[k]['adjusted'].append(computed_indexes[1])
            dicio_statistics[k]['FM'].append(computed_indexes[2])
            dicio_statistics[k]['jaccard'].append(computed_indexes[3])
    
    #obtain the average cluster external indexes for each number of clusters and show the results in a table
    rand_avg = []
    adjusted_avg = []
    FM_avg = []
    jaccard_avg = []
    table = []
    #obtain the standard deviation of adjusted rand index for each number of clusters
    adjusted_std = []
    
    for k in range(2,20):
        rand_avg.append(mean(dicio_statistics[k]['rand']))
        adjusted_avg.append(mean(dicio_statistics[k]['adjusted']))
        FM_avg.append(mean(dicio_statistics[k]['FM']))
        jaccard_avg.append(mean(dicio_statistics[k]['jaccard']))
        table.append([k,mean(dicio_statistics[k]['rand']),mean(dicio_statistics[k]['adjusted']),mean(dicio_statistics[k]['FM']),mean(dicio_statistics[k]['jaccard'])])
        adjusted_std.append(stdev(dicio_statistics[k]['adjusted']))
        
    table_results = tabulate(table, headers=['Number of clusters', 'Rand','Adjusted Rand','Fowlkes and Mallows','Jaccard'])
    print(table_results)
    
    #bar chart of standard deviation
    #plt.figure(figsize=(5, 2))
    width = 1/1.5
    plt.title('Standard Deviation of Adjusted Rand Index versus number of clusters')
    plt.bar(range(2,20), adjusted_std, width, color="blue")
    plt.show()
# Out:
# Cophenetic Correlation Coefficient: 0.804647965134
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804647965134
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804647965134
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804647965134
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804647965134
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.804647965134
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.994745         0.800868               0.997343   0.994699
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984398         0.841458               0.991813   0.98371
#                   12  0.983122         0.843934               0.991095   0.982289
#                   13  0.981779         0.844801               0.990337   0.98079
#                   14  0.980544         0.846946               0.989624   0.979378
#                   15  0.979023         0.846027               0.988753   0.977658
#                   16  0.977655         0.845895               0.987958   0.976091
#                   17  0.976273         0.845931               0.987144   0.974484
#                   18  0.974777         0.844898               0.986263   0.972747
#                   19  0.973243         0.843674               0.98535    0.970949
# Cophenetic Correlation Coefficient: 0.821519248817
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998214         0.716                  0.999106   0.998214
#                    3  0.996538         0.791139               0.998257   0.996522
#                    4  0.995272         0.831651               0.997607   0.995224
#                    5  0.993488         0.827838               0.996688   0.993395
#                    6  0.992013         0.833839               0.995918   0.991862
#                    7  0.990772         0.843734               0.995256   0.990545
#                    8  0.989264         0.844657               0.994452   0.988948
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984472         0.842274               0.991851   0.983787
#                   12  0.982926         0.841916               0.990993   0.982086
#                   13  0.981338         0.840726               0.990105   0.980331
#                   14  0.979761         0.839722               0.989214   0.97857
#                   15  0.978557         0.841737               0.988512   0.977183
#                   16  0.977339         0.84356                0.987791   0.975759
#                   17  0.975912         0.843727               0.986948   0.974094
#                   18  0.974659         0.844443               0.986195   0.972612
#                   19  0.972884         0.841652               0.985153   0.970559
# Cophenetic Correlation Coefficient: 0.851665372087
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998114         0.707975               0.999055   0.998114
#                    3  0.996338         0.783089               0.998156   0.996322
#                    4  0.994974         0.823575               0.997455   0.994926
#                    5  0.993191         0.821752               0.996536   0.993096
#                    6  0.991766         0.82976                0.99579    0.991611
#                    7  0.990624         0.841564               0.99518    0.990394
#                    8  0.989215         0.844025               0.994427   0.988897
#                    9  0.987839         0.847008               0.993682   0.987417
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984472         0.842274               0.991851   0.983787
#                   12  0.982877         0.841533               0.990967   0.982034
#                   13  0.981387         0.841173               0.990132   0.980383
#                   14  0.979517         0.8378                 0.989085   0.978313
#                   15  0.977949         0.836893               0.988189   0.976544
#                   16  0.976633         0.837892               0.987418   0.975025
#                   17  0.975206         0.83829                0.986576   0.973363
#                   18  0.973933         0.839391               0.985808   0.971849
#                   19  0.972713         0.840339               0.985064   0.970387
# Cophenetic Correlation Coefficient: 0.872027248251
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.997537         0.659836               0.998765   0.997537
#                    3  0.995389         0.737596               0.997677   0.995376
#                    4  0.993681         0.782379               0.996797   0.993635
#                    5  0.992351         0.807504               0.996103   0.99225
#                    6  0.991203         0.825092               0.995495   0.991035
#                    7  0.989836         0.830931               0.99477    0.989591
#                    8  0.988648         0.83727                0.994132   0.988312
#                    9  0.98732          0.839394               0.993415   0.986888
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984472         0.842274               0.991851   0.983787
#                   12  0.982827         0.840784               0.990942   0.981987
#                   13  0.981387         0.841173               0.990132   0.980383
#                   14  0.979469         0.837485               0.989058   0.978261
#                   15  0.978192         0.838905               0.988318   0.9768
#                   16  0.976633         0.837892               0.987418   0.975025
#                   17  0.975254         0.838575               0.986602   0.973415
#                   18  0.974027         0.839699               0.985863   0.971959
#                   19  0.972834         0.841176               0.985128   0.970512
# Cophenetic Correlation Coefficient: 0.871029932243
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.998189         0.712                  0.999093   0.998189
#                    3  0.996688         0.797873               0.998333   0.996673
#                    4  0.995422         0.835725               0.997683   0.995376
#                    5  0.993889         0.841888               0.99689    0.993797
#                    6  0.992439         0.847157               0.996131   0.992286
#                    7  0.990822         0.845275               0.995281   0.990595
#                    8  0.989091         0.842659               0.994363   0.988769
#                    9  0.987467         0.84095                0.993492   0.987042
#                   10  0.986249         0.845558               0.99282    0.985707
#                   11  0.984472         0.842274               0.991851   0.983787
#                   12  0.982924         0.84155                0.990994   0.98209
#                   13  0.981242         0.840102               0.990053   0.980228
#                   14  0.97986          0.840876               0.989264   0.978669
#                   15  0.978192         0.838905               0.988318   0.9768
#                   16  0.976633         0.837892               0.987418   0.975025
#                   17  0.975254         0.838575               0.986602   0.973415
#                   18  0.974027         0.839699               0.985863   0.971959
#                   19  0.972834         0.841176               0.985128   0.970512
# Cophenetic Correlation Coefficient: 0.170303380733
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.911701         0.757248               0.945498   0.898911
#                    3  0.862148         0.722527               0.886507   0.803338
#                    4  0.825016         0.662751               0.828711   0.704815
#                    5  0.852701         0.712261               0.848178   0.735963
#                    6  0.852732         0.712309               0.848192   0.73598
#                    7  0.853478         0.713611               0.848694   0.73685
#                    8  0.855538         0.717136               0.849907   0.738913
#                    9  0.862162         0.728844               0.854601   0.746849
#                   10  0.872721         0.747065               0.861302   0.758066
#                   11  0.876792         0.753315               0.86261    0.760373
#                   12  0.882492         0.762005               0.86439    0.763452
#                   13  0.883492         0.76212                0.862567   0.760484
#                   14  0.885512         0.764614               0.862097   0.759522
#                   15  0.888759         0.76852                0.861691   0.758703
#                   16  0.893924         0.777572               0.865273   0.764158
#                   17  0.909792         0.809418               0.882996   0.792058
#                   18  0.909927         0.809303               0.882533   0.791295
#                   19  0.910043         0.809338               0.882355   0.790983
# Cophenetic Correlation Coefficient: 0.815317224986
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.911513         0.439479               0.951556   0.907132
#                    3  0.897013         0.511433               0.941689   0.889548
#                    4  0.887501         0.610595               0.931865   0.872522
#                    5  0.884303         0.637399               0.928066   0.865683
#                    6  0.898268         0.738353               0.932297   0.871825
#                    7  0.905157         0.759109               0.9362     0.87908
#                    8  0.907823         0.766679               0.937801   0.882035
#                    9  0.909947         0.772881               0.939045   0.884268
#                   10  0.910002         0.773086               0.939065   0.884312
#                   11  0.910957         0.775902               0.939596   0.885299
#                   12  0.915556         0.789813               0.942202   0.890179
#                   13  0.918484         0.798629               0.943838   0.893217
#                   14  0.922049         0.809841               0.945688   0.896766
#                   15  0.925507         0.820098               0.947624   0.900375
#                   16  0.928141         0.828258               0.949024   0.90299
#                   17  0.929588         0.833165               0.949656   0.904169
#                   18  0.93199          0.840472               0.950957   0.906526
#                   19  0.933869         0.845598               0.952113   0.90864
# Cophenetic Correlation Coefficient: 0.740931707532
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.919685         0.807294               0.943163   0.89273
#                    3  0.913827         0.797052               0.938316   0.884111
#                    4  0.903189         0.783848               0.927784   0.867373
#                    5  0.881946         0.749392               0.909081   0.837033
#                    6  0.829219         0.661119               0.862762   0.761879
#                    7  0.783826         0.584379               0.823222   0.696676
#                    8  0.8468           0.696117               0.834829   0.715755
#                    9  0.880925         0.756739               0.859887   0.755721
#                   10  0.890373         0.773125               0.866122   0.765711
#                   11  0.895876         0.782775               0.86994    0.771736
#                   12  0.897287         0.785214               0.870878   0.773183
#                   13  0.898202         0.786867               0.871616   0.774341
#                   14  0.898172         0.786719               0.871442   0.774011
#                   15  0.898882         0.787799               0.871681   0.774347
#                   16  0.900131         0.78962                0.87192    0.774613
#                   17  0.902176         0.792814               0.872714   0.775574
#                   18  0.904596         0.79675                0.87394    0.777122
#                   19  0.918037         0.821536               0.885865   0.796105
# Cophenetic Correlation Coefficient: 0.652203467918
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.77076          0.517532               0.819337   0.696787
#                    3  0.831758         0.6503                 0.791387   0.656783
#                    4  0.834537         0.647452               0.780578   0.641243
#                    5  0.834365         0.64284                0.774082   0.632967
#                    6  0.854635         0.677891               0.789889   0.653463
#                    7  0.856755         0.678157               0.787038   0.650783
#                    8  0.857305         0.675411               0.782629   0.645907
#                    9  0.861868         0.678361               0.780265   0.643538
#                   10  0.854317         0.655026               0.76108    0.618524
#                   11  0.8464           0.629884               0.740513   0.591468
#                   12  0.844707         0.62217                0.733738   0.581975
#                   13  0.84232          0.614261               0.727224   0.573102
#                   14  0.84061          0.607889               0.72192    0.565531
#                   15  0.863996         0.621162               0.713886   0.550416
#                   16  0.867582         0.627713               0.717596   0.555542
#                   17  0.868549         0.629471               0.718558   0.556839
#                   18  0.868547         0.62936                0.718425   0.556712
#                   19  0.86903          0.63031                0.718963   0.557565
# Cophenetic Correlation Coefficient: 0.596430253604
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.78301          0.481572               0.847262   0.75011
#                    3  0.783466         0.549249               0.72996    0.577891
#                    4  0.761614         0.452275               0.627432   0.460256
#                    5  0.816512         0.523633               0.649255   0.478206
#                    6  0.851389         0.584027               0.684785   0.515608
#                    7  0.862721         0.597897               0.689304   0.522159
#                    8  0.873056         0.61668                0.700093   0.536505
#                    9  0.880418         0.629954               0.707738   0.546588
#                   10  0.885445         0.637641               0.711147   0.551801
#                   11  0.892904         0.650911               0.719316   0.561644
#                   12  0.896446         0.655392               0.720708   0.564285
#                   13  0.898938         0.658188               0.721493   0.565628
#                   14  0.90103          0.658853               0.720461   0.564706
#                   15  0.902094         0.657184               0.71778    0.561582
#                   16  0.906967         0.665695               0.722928   0.568277
#                   17  0.909556         0.668242               0.723635   0.569525
#                   18  0.910439         0.667598               0.722198   0.568082
#                   19  0.911478         0.668489               0.722311   0.568368
# Cophenetic Correlation Coefficient: 0.580255399959
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.850624         0.614473               0.897542   0.823512
#                    3  0.838958         0.675641               0.822313   0.705112
#                    4  0.843695         0.649631               0.768017   0.631024
#                    5  0.844983         0.627443               0.738531   0.591001
#                    6  0.852103         0.606206               0.707079   0.550784
#                    7  0.866581         0.563762               0.647957   0.480094
#                    8  0.883785         0.58884                0.660362   0.495421
#                    9  0.889545         0.593549               0.660347   0.496668
#                   10  0.89663          0.60476                0.666742   0.504213
#                   11  0.900257         0.610777               0.670229   0.508398
#                   12  0.904112         0.617344               0.674237   0.513158
#                   13  0.90568          0.618325               0.674085   0.513028
#                   14  0.906744         0.6175                 0.672557   0.511178
#                   15  0.907687         0.615997               0.670447   0.508183
#                   16  0.910778         0.617781               0.670102   0.507512
#                   17  0.911951         0.617178               0.668906   0.505882
#                   18  0.912557         0.614336               0.666009   0.501919
#                   19  0.913959         0.613672               0.664863   0.499805
# Cophenetic Correlation Coefficient: 0.564194651707
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.877662         0.626872               0.921598   0.860397
#                    3  0.742459         0.4935                 0.746416   0.602438
#                    4  0.80573          0.577201               0.728923   0.58222
#                    5  0.826783         0.590265               0.715716   0.566056
#                    6  0.844789         0.556631               0.65887    0.492268
#                    7  0.88689          0.624576               0.695514   0.53525
#                    8  0.89343          0.608397               0.673488   0.509932
#                    9  0.895849         0.595426               0.65786    0.493081
#                   10  0.898652         0.574749               0.635167   0.467344
#                   11  0.903445         0.580417               0.637057   0.470449
#                   12  0.906314         0.574678               0.629084   0.461838
#                   13  0.908973         0.572969               0.625523   0.458131
#                   14  0.912139         0.570084               0.620603   0.452833
#                   15  0.913629         0.567875               0.617593   0.449159
#                   16  0.916566         0.566363               0.61419    0.44548
#                   17  0.918195         0.56576                0.612822   0.443626
#                   18  0.919595         0.56546                0.612238   0.442313
#                   19  0.930906         0.571732               0.610813   0.440439
# Cophenetic Correlation Coefficient: 0.558114073046
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.803154         0.404512               0.878366   0.784161
#                    3  0.660796         0.352881               0.661234   0.480922
#                    4  0.758117         0.478751               0.666604   0.498727
#                    5  0.793392         0.508371               0.657145   0.492652
#                    6  0.797546         0.479305               0.618396   0.44907
#                    7  0.841824         0.510314               0.610445   0.440236
#                    8  0.852988         0.501477               0.591788   0.421257
#                    9  0.858495         0.500462               0.586746   0.415848
#                   10  0.867715         0.501304               0.580835   0.410103
#                   11  0.881713         0.51286                0.582492   0.412517
#                   12  0.898585         0.528056               0.587063   0.415967
#                   13  0.902938         0.528775               0.58455    0.414257
#                   14  0.90497          0.511951               0.56614    0.396068
#                   15  0.908096         0.510349               0.56236    0.392697
#                   16  0.91352          0.513301               0.561964   0.392086
#                   17  0.917187         0.520381               0.566738   0.396949
#                   18  0.919988         0.522812               0.567579   0.397602
#                   19  0.922572         0.520591               0.563839   0.39401
# Cophenetic Correlation Coefficient: 0.595328987317
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.82884         0.0419381               0.902982   0.826223
#                    3  0.683633        0.308924                0.765701   0.620759
#                    4  0.731277        0.456908                0.69866    0.545281
#                    5  0.765334        0.446539                0.615723   0.442181
#                    6  0.81147         0.50663                 0.634687   0.469727
#                    7  0.832188        0.528029                0.638446   0.473856
#                    8  0.845481        0.511296                0.608292   0.4421
#                    9  0.876365        0.543109                0.61999    0.447363
#                   10  0.889304        0.565848                0.633032   0.463437
#                   11  0.897484        0.580624                0.641376   0.474101
#                   12  0.903226        0.585509                0.642189   0.475262
#                   13  0.906473        0.585744                0.640305   0.472932
#                   14  0.908903        0.584311                0.637909   0.469401
#                   15  0.911096        0.572419                0.62453    0.454694
#                   16  0.921814        0.577602                0.622001   0.452728
#                   17  0.924393        0.572891                0.615552   0.445974
#                   18  0.925535        0.54437                 0.586384   0.415557
#                   19  0.92821         0.53974                 0.580283   0.409202
# Cophenetic Correlation Coefficient: 0.602061998255
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.899017         0.370287               0.94549    0.898822
#                    3  0.697131         0.281563               0.787014   0.648341
#                    4  0.675817         0.348941               0.636973   0.469612
#                    5  0.750149         0.448509               0.638002   0.471816
#                    6  0.782919         0.481646               0.637511   0.473312
#                    7  0.79958          0.490508               0.629009   0.462915
#                    8  0.806622         0.479311               0.609458   0.44082
#                    9  0.830719         0.483726               0.591717   0.423812
#                   10  0.862762         0.520925               0.605156   0.436268
#                   11  0.869702         0.526724               0.605992   0.436887
#                   12  0.890073         0.542775               0.608237   0.43673
#                   13  0.900319         0.558745               0.617338   0.446852
#                   14  0.904827         0.564607               0.619873   0.450409
#                   15  0.909263         0.56748                0.619871   0.45048
#                   16  0.915202         0.566862               0.615314   0.446099
#                   17  0.917395         0.56593                0.613011   0.443623
#                   18  0.920718         0.567071               0.612133   0.442491
#                   19  0.927006         0.574289               0.615295   0.445683
# Cophenetic Correlation Coefficient: 0.643621705622
#   Number of clusters      Rand    Adjusted Rand    Fowlkes and Mallows    Jaccard
# --------------------  --------  ---------------  ---------------------  ---------
#                    2  0.903863         0.384222               0.947858   0.903681
#                    3  0.681741         0.17667                0.80635    0.668468
#                    4  0.752851         0.505416               0.762313   0.621994
#                    5  0.78275          0.563076               0.754245   0.614502
#                    6  0.778234         0.477067               0.637479   0.467494
#                    7  0.813248         0.525255               0.654308   0.490972
#                    8  0.830544         0.546626               0.660809   0.498701
#                    9  0.833105         0.534584               0.645676   0.479885
#                   10  0.839761         0.500216               0.601393   0.435741
#                   11  0.865064         0.519588               0.601915   0.433119
#                   12  0.87655          0.53597                0.610181   0.442044
#                   13  0.88626          0.552241               0.619917   0.452568
#                   14  0.894455         0.565386               0.627811   0.46069
#                   15  0.908466         0.565172               0.619862   0.447392
#                   16  0.914064         0.567207               0.618741   0.445498
#                   17  0.918114         0.573707               0.621538   0.450318
#                   18  0.923265         0.577699               0.622357   0.451204
#                   19  0.925829         0.577444               0.620083   0.449577
